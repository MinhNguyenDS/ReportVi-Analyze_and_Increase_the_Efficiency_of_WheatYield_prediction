# %% [markdown]
# # Đọc dữ liệu

# %%
import pandas as pd 

df_2016 = pd.read_csv('2016_Data.csv')
df_2017 = pd.read_csv('2017_Data.csv')
df_2018 = pd.read_csv('2018_Data.csv')
df_2019 = pd.read_csv('2019_Data.csv')
df_2020 = pd.read_csv('2020_Data.csv')

# %% [markdown]
# # Khảo sát sơ bộ

# %%
df_2016.head()
# Out:
#    plot_id  trial  rep  range  column  entry  CT_20160123  CT_20160204  \
# 0     1001      1    1      1       1   1001         14.4         22.4
# 1     1002      1    1      1       2   1002         15.1         22.8
# 2     1003      1    1      1       3   1003         14.0         22.1
# 3     1004      1    1      1       4   1004         14.5         22.0
# 4     1005      1    1      1       5   1005         13.5         22.3
#
#    CT_20160212  CT_20160223  ...  NDVI_20160315  DTHD  DAYSMT   PH   SN  \
# 0         21.1         23.5  ...           0.26    74     106  100  254
# 1         22.2         23.0  ...           0.18    70     105  107  247
# 2         22.2         23.5  ...           0.16    73     104  100  260
# 3         22.3         24.1  ...           0.21    75     104   95  293
# 4         21.7         24.5  ...           0.18    70     104  106  237
#
#    SPKLNG  SPLN  GRNSPK    TGW  GRYLD
# 0    10.0  19.2    41.6  38.46   2.50
# ...

# %%
df_2017.head()
# Out:
#           plot_id  trial  range  column  entry  rep  CT_20170104  CT_20170109  \
# 0  17SABWGPYT1001      1      1       1   1001    1         21.2         23.2
# 1  17SABWGPYT1002      1      1       2   1002    1         23.2         24.9
# 2  17SABWGPYT1003      1      1       3   1003    1         20.8         22.0
# 3  17SABWGPYT1004      1      1       4   1004    1         21.5         23.6
# 4  17SABWGPYT1005      1      1       5   1005    1         21.0         22.3
#
#    CT_20170114  CT_20170120  ...  NDVI_20170313  DTHD  DAYSMT    PH     SN  \
# 0         19.5         21.1  ...           0.24  73.0   110.0  93.0  286.0
# 1         19.3         22.3  ...           0.22  69.0   109.0  98.0  183.0
# 2         19.4         20.9  ...           0.23  61.0   103.0  99.0  304.0
# 3         20.3         22.4  ...           0.37  71.0   109.0  96.0  313.0
# 4         19.6         21.1  ...           0.27  73.0   110.0  97.0  342.0
#
#    SPKLNG  SPLN  GRNSPK   TGW  GRYLD
# ...

# %%
df_2018.head()
# Out:
#           plot_id  trial  range  column  entry  rep  CT_20180126  CT_20180131  \
# 0  18SABWGPYT1001      1      1       1   1001    1         23.5         21.9
# 1  18SABWGPYT1002      1      1       2   1002    1         24.9         23.3
# 2  18SABWGPYT1003      1      1       3   1003    1         25.6         23.6
# 3  18SABWGPYT1004      1      1       4   1004    1         24.1         22.8
# 4  18SABWGPYT1005      1      1       5   1005    1         23.8         22.3
#
#    CT_20180205  CT_20180210  ...  NDVI_20180320  DTHD  DAYSMT    PH     SN  \
# 0         24.7         22.2  ...           0.44  74.0   106.0  82.0  207.0
# 1         26.3         23.3  ...           0.34  73.0   105.0  85.0  128.0
# 2         26.0         23.5  ...           0.54  75.0   106.0  82.0  139.0
# 3         25.3         24.0  ...           0.27  86.0   109.0  87.0   89.0
# 4         25.2         22.8  ...           0.49  86.0   110.0  93.0  147.0
#
#    SPKLNG  SPLN  GRNSPK   TGW  GRYLD
# ...

# %%
df_2019.head()
# Out:
#           plot_id  trial  range  column  entry  rep  CT_20190123  CT_20190127  \
# 0  19SABWGPYT1001      1      1       1   1001    1         22.0         24.1
# 1  19SABWGPYT1002      1      1       2   1002    1         22.8         23.2
# 2  19SABWGPYT1003      1      1       3   1003    1         22.9         24.7
# 3  19SABWGPYT1004      1      1       4   1004    1         22.7         23.8
# 4  19SABWGPYT1005      1      1       5   1005    1         23.3         24.9
#
#    CT_20190131  CT_20190205  ...  NDVI_20190325  DTHD  DAYSMT  PH   SN  \
# 0         23.3         23.5  ...           0.16    72     102  82  174
# 1         21.2         22.8  ...           0.24    64     101  89  191
# 2         23.2         23.5  ...           0.23    80     112  86  160
# 3         22.3         24.5  ...           0.42    77     111  91  190
# 4         23.9         24.0  ...           0.32    78     114  91  171
#
#    SPKLNG  SPLN  GRNSPK     TGW  GRYLD
# ...

# %%
df_2020.head()
# Out:
#           plot_id  trial  range  column  entry  rep  CT_20200112  CT_20200116  \
# 0  20SABWGPYT1001      1      1       1   1001    1         23.1         25.1
# 1  20SABWGPYT1002      1      1       2   1002    1         23.2         24.2
# 2  20SABWGPYT1003      1      1       3   1003    1         23.9         24.6
# 3  20SABWGPYT1004      1      1       4   1004    1         22.8         24.6
# 4  20SABWGPYT1005      1      1       5   1005    1         23.8         24.9
#
#    CT_20200121  CT_20200126  ...  NDVI_20200318  NDVI_20200323  DTHD  DAYSMT  \
# 0         23.2         25.1  ...           0.52           0.45  71.0   106.0
# 1         21.3         21.3  ...           0.23           0.40  64.0   103.0
# 2         22.1         20.6  ...           0.62           0.30  75.0   103.0
# 3         22.2         21.5  ...           0.49           0.25  70.0   103.0
# 4         23.1         20.1  ...           0.49           0.52  71.0   105.0
#
# ...

# %%
df_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   plot_id        1200 non-null   int64
#  1   trial          1200 non-null   int64
#  2   rep            1200 non-null   int64
#  3   range          1200 non-null   int64
#  4   column         1200 non-null   int64
#  5   entry          1200 non-null   int64
#  6   CT_20160123    1200 non-null   float64
#  7   CT_20160204    1200 non-null   float64
#  8   CT_20160212    1200 non-null   float64
#  9   CT_20160223    1200 non-null   float64
#  10  CT_20160228    1200 non-null   float64
#  11  CT_20160302    1200 non-null   float64
#  12  CT_20160309    1200 non-null   float64
#  13  CT_20160315    1200 non-null   float64
#  14  NDVI_20160121  1200 non-null   float64
#  15  NDVI_20160130  1200 non-null   float64
#  16  NDVI_20160203  1200 non-null   float64
# ...

# %%
df_2016.describe().transpose()
# Out:
#                 count         mean          std      min        25%      50%  \
# plot_id        1200.0  5560.500000  2873.687814  1001.00  3060.7500  5560.50
# trial          1200.0     5.500000     2.873479     1.00     3.0000     5.50
# rep            1200.0     1.500000     0.500208     1.00     1.0000     1.50
# range          1200.0     6.500000     3.453492     1.00     3.7500     6.50
# column         1200.0     5.750000     3.140443     1.00     3.0000     6.00
# entry          1200.0  5530.500000  2873.531086  1001.00  3030.7500  5530.50
# CT_20160123    1200.0    18.013750     2.113427    13.50    16.3000    18.20
# CT_20160204    1200.0    20.827583     1.568316    16.10    19.6000    20.80
# CT_20160212    1200.0    24.527583     0.885805    19.90    24.0000    24.50
# CT_20160223    1200.0    25.218083     1.172587    20.20    24.3750    25.30
# CT_20160228    1200.0    28.024600     1.377573    22.70    27.2000    28.20
# ...

# %% [markdown]
# # Tiền xử lý dữ liệu

# %% [markdown]
# ## Kiểm tra và xử lý các dữ liệu bị mất

# %%
df_2020.isnull().sum()
# Out:
# plot_id          0
# trial            0
# range            0
# column           0
# entry            0
# rep              0
# CT_20200112      2
# CT_20200116      2
# CT_20200121      2
# CT_20200126      2
# CT_20200130      2
# CT_20200205      2
# CT_20200210      2
# CT_20200215      2
# CT_20200220      2
# CT_20200226      2
# CT_20200302      2
# CT_20200308      2
# CT_20200313      2
# CT_20200318      2
# CT_20200323      2
# NDVI_20200112    2
# NDVI_20200116    2
# NDVI_20200121    2
# NDVI_20200126    2
# NDVI_20200130    2
# NDVI_20200205    2
# NDVI_20200210    2
# NDVI_20200215    2
# NDVI_20200220    2
# NDVI_20200226    2
# NDVI_20200302    2
# NDVI_20200308    2
# NDVI_20200313    2
# NDVI_20200318    2
# NDVI_20200323    2
# DTHD             2
# DAYSMT           2
# PH               2
# SN               2
# SPLN             2
# GRNSPK           2
# TGW              2
# GRYLD            2
# dtype: int64

# %%
df_2017=df_2017.fillna(df_2017.mean())
df_2018=df_2018.fillna(df_2018.mean())
df_2020=df_2020.fillna(df_2020.mean())
# Out:
# C:\Users\minhn\AppData\Local\Temp/ipykernel_9688/2242243767.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2017=df_2017.fillna(df_2017.mean())
# C:\Users\minhn\AppData\Local\Temp/ipykernel_9688/2242243767.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2018=df_2018.fillna(df_2018.mean())
# C:\Users\minhn\AppData\Local\Temp/ipykernel_9688/2242243767.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_2020=df_2020.fillna(df_2020.mean())

# %%
df_2020.count()
# Out:
# plot_id          1320
# trial            1320
# range            1320
# column           1320
# entry            1320
# rep              1320
# CT_20200112      1320
# CT_20200116      1320
# CT_20200121      1320
# CT_20200126      1320
# CT_20200130      1320
# CT_20200205      1320
# CT_20200210      1320
# CT_20200215      1320
# CT_20200220      1320
# CT_20200226      1320
# CT_20200302      1320
# CT_20200308      1320
# CT_20200313      1320
# CT_20200318      1320
# CT_20200323      1320
# NDVI_20200112    1320
# NDVI_20200116    1320
# NDVI_20200121    1320
# NDVI_20200126    1320
# NDVI_20200130    1320
# NDVI_20200205    1320
# NDVI_20200210    1320
# NDVI_20200215    1320
# NDVI_20200220    1320
# NDVI_20200226    1320
# NDVI_20200302    1320
# NDVI_20200308    1320
# NDVI_20200313    1320
# NDVI_20200318    1320
# NDVI_20200323    1320
# DTHD             1320
# DAYSMT           1320
# PH               1320
# SN               1320
# SPLN             1320
# ...

# %% [markdown]
# # Trực quan hóa dữ liệu kiểm tra độ phụ thuộc của các thuộc tính

# %% [markdown]
# ## Vẽ ma trận tương quan giữa các thuộc tính

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.subplots(figsize = (20, 20))
sns.heatmap(df_2016.corr(),square = True,cbar=True,annot=True,annot_kws={'size': 8});

# %% [markdown]
# ## Xem mối quan hệ giữa các thuộc tính đã chọn và với thuộc tính đích

# %%
import seaborn as sns
sns.histplot(df_2016['GRYLD']);

# %%
sns.histplot(df_2017['GRYLD']);

# %%
sns.histplot(df_2018['GRYLD']);

# %%
sns.histplot(df_2019['GRYLD']);

# %%
sns.histplot(df_2020['GRYLD']);

# %%
from sklearn.model_selection import train_test_split
X_CT_2016 = df_2016[['CT_20160123', 'CT_20160204', 'CT_20160212', 'CT_20160223', 'CT_20160228', 'CT_20160302', 'CT_20160309', 'CT_20160315']]
X_CT_2017 = df_2017[['CT_20170104', 'CT_20170109', 'CT_20170114', 'CT_20170120', 'CT_20170125', 'CT_20170131', 'CT_20170205', 'CT_20170210','CT_20170215','CT_20170221','CT_20170225','CT_20170302','CT_20170307','CT_20170313']]
X_CT_2018 = df_2018[['CT_20180126', 'CT_20180131', 'CT_20180205', 'CT_20180210', 'CT_20180214', 'CT_20180219', 'CT_20180225', 'CT_20180301','CT_20180305','CT_20180310','CT_20180315','CT_20180320']]
X_CT_2019 = df_2019[['CT_20190123', 'CT_20190127', 'CT_20190131', 'CT_20190205', 'CT_20190211', 'CT_20190218', 'CT_20190223', 'CT_20190301','CT_20190305','CT_20190311','CT_20190316','CT_20190320','CT_20190325']]
X_CT_2020 = df_2020[['CT_20200112', 'CT_20200116', 'CT_20200121', 'CT_20200126', 'CT_20200130', 'CT_20200205', 'CT_20200210', 'CT_20200215','CT_20200220','CT_20200226','CT_20200302','CT_20200308','CT_20200313','CT_20200318','CT_20200323']]

# %%
X_NDVI_2016 = df_2016[['NDVI_20160121','NDVI_20160130','NDVI_20160203','NDVI_20160207','NDVI_20160223','NDVI_20160228','NDVI_20160303','NDVI_20160310','NDVI_20160315']]
X_NDVI_2017 = df_2017[['NDVI_20170103','NDVI_20170108','NDVI_20170114','NDVI_20170120','NDVI_20170125','NDVI_20170131','NDVI_20170205','NDVI_20170210','NDVI_20170215','NDVI_20170220','NDVI_20170225','NDVI_20170302','NDVI_20170307','NDVI_20170313']]
X_NDVI_2018 = df_2018[['NDVI_20180126','NDVI_20180131','NDVI_20180204','NDVI_20180210','NDVI_20180214','NDVI_20180219','NDVI_20180226','NDVI_20180301','NDVI_20180305','NDVI_20180310','NDVI_20180315','NDVI_20180320']]
X_NDVI_2019 = df_2019[['NDVI_20190121','NDVI_20190127','NDVI_20190131','NDVI_20190205','NDVI_20190211','NDVI_20190218','NDVI_20190222','NDVI_20190228','NDVI_20190305','NDVI_20190311','NDVI_20190315','NDVI_20190320','NDVI_20190325']]
X_NDVI_2020 = df_2020[['NDVI_20200112','NDVI_20200116','NDVI_20200121','NDVI_20200126','NDVI_20200130','NDVI_20200205','NDVI_20200210','NDVI_20200215','NDVI_20200220','NDVI_20200226','NDVI_20200302','NDVI_20200308','NDVI_20200313','NDVI_20200318','NDVI_20200323']]

# %%
X_NDVI_CT_2016 = df_2016[['CT_20160123', 'CT_20160204', 'CT_20160212', 'CT_20160223', 'CT_20160228', 'CT_20160302', 'CT_20160309', 'CT_20160315','NDVI_20160121','NDVI_20160130','NDVI_20160203','NDVI_20160207','NDVI_20160223','NDVI_20160228','NDVI_20160303','NDVI_20160310','NDVI_20160315']]
X_NDVI_CT_2017 = df_2017[['CT_20170104', 'CT_20170109', 'CT_20170114', 'CT_20170120', 'CT_20170125', 'CT_20170131', 'CT_20170205', 'CT_20170210','CT_20170215','CT_20170221','CT_20170225','CT_20170302','CT_20170307','CT_20170313','NDVI_20170103','NDVI_20170108','NDVI_20170114','NDVI_20170120','NDVI_20170125','NDVI_20170131','NDVI_20170205','NDVI_20170210','NDVI_20170215','NDVI_20170220','NDVI_20170225','NDVI_20170302','NDVI_20170307','NDVI_20170313']]
X_NDVI_CT_2018 = df_2018[['CT_20180126', 'CT_20180131', 'CT_20180205', 'CT_20180210', 'CT_20180214', 'CT_20180219', 'CT_20180225', 'CT_20180301','CT_20180305','CT_20180310','CT_20180315','CT_20180320','NDVI_20180126','NDVI_20180131','NDVI_20180204','NDVI_20180210','NDVI_20180214','NDVI_20180219','NDVI_20180226','NDVI_20180301','NDVI_20180305','NDVI_20180310','NDVI_20180315','NDVI_20180320']]
X_NDVI_CT_2019 = df_2019[['CT_20190123', 'CT_20190127', 'CT_20190131', 'CT_20190205', 'CT_20190211', 'CT_20190218', 'CT_20190223', 'CT_20190301','CT_20190305','CT_20190311','CT_20190316','CT_20190320','CT_20190325','NDVI_20190121','NDVI_20190127','NDVI_20190131','NDVI_20190205','NDVI_20190211','NDVI_20190218','NDVI_20190222','NDVI_20190228','NDVI_20190305','NDVI_20190311','NDVI_20190315','NDVI_20190320','NDVI_20190325']]
X_NDVI_CT_2020 = df_2020[['CT_20200112', 'CT_20200116', 'CT_20200121', 'CT_20200126', 'CT_20200130', 'CT_20200205', 'CT_20200210', 'CT_20200215','CT_20200220','CT_20200226','CT_20200302','CT_20200308','CT_20200313','CT_20200318','CT_20200323','NDVI_20200112','NDVI_20200116','NDVI_20200121','NDVI_20200126','NDVI_20200130','NDVI_20200205','NDVI_20200210','NDVI_20200215','NDVI_20200220','NDVI_20200226','NDVI_20200302','NDVI_20200308','NDVI_20200313','NDVI_20200318','NDVI_20200323']]

# %%
X_AGR_2016 = df_2016[['DTHD','DAYSMT','PH','SN','SPKLNG','SPLN','GRNSPK','TGW']]
X_AGR_2017 = df_2017[['DTHD','DAYSMT','PH','SN','SPKLNG','SPLN','GRNSPK','TGW']]
X_AGR_2018 = df_2018[['DTHD','DAYSMT','PH','SN','SPKLNG','SPLN','GRNSPK','TGW']]
X_AGR_2019 = df_2019[['DTHD','DAYSMT','PH','SN','SPKLNG','SPLN','GRNSPK','TGW']]
X_AGR_2020 = df_2020[['DTHD','DAYSMT','PH','SN','SPLN','GRNSPK','TGW']]

# %%
X_ALL_2016 = df_2016.drop(['plot_id','trial','rep','range','column','entry','GRYLD'],axis=1)
X_ALL_2017 = df_2017.drop(['plot_id','trial','rep','range','column','entry','GRYLD'],axis=1)
X_ALL_2018 = df_2018.drop(['plot_id','trial','rep','range','column','entry','GRYLD'],axis=1)
X_ALL_2019 = df_2019.drop(['plot_id','trial','rep','range','column','entry','GRYLD'],axis=1)
X_ALL_2020 = df_2020.drop(['plot_id','trial','rep','range','column','entry','GRYLD'],axis=1)

# %%
y_2016 = df_2016['GRYLD']
y_2017 = df_2017['GRYLD']
y_2018 = df_2018['GRYLD']
y_2019 = df_2019['GRYLD']
y_2020 = df_2020['GRYLD']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_CT_2016.iloc[:, :5] = sc.fit_transform(X_CT_2016.iloc[:, :5])
X_CT_2017.iloc[:, :5] = sc.fit_transform(X_CT_2017.iloc[:, :5])
X_CT_2018.iloc[:, :5] = sc.fit_transform(X_CT_2018.iloc[:, :5])
X_CT_2019.iloc[:, :5] = sc.fit_transform(X_CT_2019.iloc[:, :5])
X_CT_2020.iloc[:, :5] = sc.fit_transform(X_CT_2020.iloc[:, :5])
X_NDVI_2016.iloc[:, :5] = sc.fit_transform(X_NDVI_2016.iloc[:, :5])
X_NDVI_2017.iloc[:, :5] = sc.fit_transform(X_NDVI_2017.iloc[:, :5])
X_NDVI_2018.iloc[:, :5] = sc.fit_transform(X_NDVI_2018.iloc[:, :5])
X_NDVI_2019.iloc[:, :5] = sc.fit_transform(X_NDVI_2019.iloc[:, :5])
X_NDVI_2020.iloc[:, :5] = sc.fit_transform(X_NDVI_2020.iloc[:, :5])
X_NDVI_CT_2016.iloc[:, :5] = sc.fit_transform(X_NDVI_CT_2016.iloc[:, :5])
X_NDVI_CT_2017.iloc[:, :5] = sc.fit_transform(X_NDVI_CT_2017.iloc[:, :5])
X_NDVI_CT_2018.iloc[:, :5] = sc.fit_transform(X_NDVI_CT_2018.iloc[:, :5])
X_NDVI_CT_2019.iloc[:, :5] = sc.fit_transform(X_NDVI_CT_2019.iloc[:, :5])
X_NDVI_CT_2020.iloc[:, :5] = sc.fit_transform(X_NDVI_CT_2020.iloc[:, :5])
X_AGR_2016.iloc[:, :5] = sc.fit_transform(X_AGR_2016.iloc[:, :5])
X_AGR_2017.iloc[:, :5] = sc.fit_transform(X_AGR_2017.iloc[:, :5])
X_AGR_2018.iloc[:, :5] = sc.fit_transform(X_AGR_2018.iloc[:, :5])
X_AGR_2019.iloc[:, :5] = sc.fit_transform(X_AGR_2019.iloc[:, :5])
X_AGR_2020.iloc[:, :5] = sc.fit_transform(X_AGR_2020.iloc[:, :5])
X_ALL_2016.iloc[:, :5] = sc.fit_transform(X_ALL_2016.iloc[:, :5])
X_ALL_2017.iloc[:, :5] = sc.fit_transform(X_ALL_2017.iloc[:, :5])
X_ALL_2018.iloc[:, :5] = sc.fit_transform(X_ALL_2018.iloc[:, :5])
X_ALL_2019.iloc[:, :5] = sc.fit_transform(X_ALL_2019.iloc[:, :5])
X_ALL_2020.iloc[:, :5] = sc.fit_transform(X_ALL_2020.iloc[:, :5])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
X_CT_2016_train, X_CT_2016_test, y_2016_train, y_2016_test = train_test_split(X_CT_2016, y_2016, random_state=0)
X_CT_2017_train, X_CT_2017_test, y_2017_train, y_2017_test = train_test_split(X_CT_2017, y_2017, random_state=0)
X_CT_2018_train, X_CT_2018_test, y_2018_train, y_2018_test = train_test_split(X_CT_2018, y_2018, random_state=0)
X_CT_2019_train, X_CT_2019_test, y_2019_train, y_2019_test = train_test_split(X_CT_2019, y_2019, random_state=0)
X_CT_2020_train, X_CT_2020_test, y_2020_train, y_2020_test = train_test_split(X_CT_2020, y_2020, random_state=0)
X_NDVI_2016_train, X_NDVI_2016_test, y_2016_train, y_2016_test = train_test_split(X_NDVI_2016, y_2016, random_state=0)
X_NDVI_2017_train, X_NDVI_2017_test, y_2017_train, y_2017_test = train_test_split(X_NDVI_2017, y_2017, random_state=0)
X_NDVI_2018_train, X_NDVI_2018_test, y_2018_train, y_2018_test = train_test_split(X_NDVI_2018, y_2018, random_state=0)
X_NDVI_2019_train, X_NDVI_2019_test, y_2019_train, y_2019_test = train_test_split(X_NDVI_2019, y_2019, random_state=0)
X_NDVI_2020_train, X_NDVI_2020_test, y_2020_train, y_2020_test = train_test_split(X_NDVI_2020, y_2020, random_state=0)
X_NDVI_CT_2016_train, X_NDVI_CT_2016_test, y_2016_train, y_2016_test = train_test_split(X_NDVI_CT_2016, y_2016, random_state=0)
X_NDVI_CT_2017_train, X_NDVI_CT_2017_test, y_2017_train, y_2017_test = train_test_split(X_NDVI_CT_2017, y_2017, random_state=0)
X_NDVI_CT_2018_train, X_NDVI_CT_2018_test, y_2018_train, y_2018_test = train_test_split(X_NDVI_CT_2018, y_2018, random_state=0)
X_NDVI_CT_2019_train, X_NDVI_CT_2019_test, y_2019_train, y_2019_test = train_test_split(X_NDVI_CT_2019, y_2019, random_state=0)
X_NDVI_CT_2020_train, X_NDVI_CT_2020_test, y_2020_train, y_2020_test = train_test_split(X_NDVI_CT_2020, y_2020, random_state=0)
X_AGR_2016_train, X_AGR_2016_test, y_2016_train, y_2016_test = train_test_split(X_AGR_2016, y_2016, random_state=0)
X_AGR_2017_train, X_AGR_2017_test, y_2017_train, y_2017_test = train_test_split(X_AGR_2017, y_2017, random_state=0)
X_AGR_2018_train, X_AGR_2018_test, y_2018_train, y_2018_test = train_test_split(X_AGR_2018, y_2018, random_state=0)
X_AGR_2019_train, X_AGR_2019_test, y_2019_train, y_2019_test = train_test_split(X_AGR_2019, y_2019, random_state=0)
X_AGR_2020_train, X_AGR_2020_test, y_2020_train, y_2020_test = train_test_split(X_AGR_2020, y_2020, random_state=0)
X_ALL_2016_train, X_ALL_2016_test, y_2016_train, y_2016_test = train_test_split(X_ALL_2016, y_2016, random_state=0)
X_ALL_2017_train, X_ALL_2017_test, y_2017_train, y_2017_test = train_test_split(X_ALL_2017, y_2017, random_state=0)
X_ALL_2018_train, X_ALL_2018_test, y_2018_train, y_2018_test = train_test_split(X_ALL_2018, y_2018, random_state=0)
X_ALL_2019_train, X_ALL_2019_test, y_2019_train, y_2019_test = train_test_split(X_ALL_2019, y_2019, random_state=0)
X_ALL_2020_train, X_ALL_2020_test, y_2020_train, y_2020_test = train_test_split(X_ALL_2020, y_2020, random_state=0)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVR
#Mô hình dự đoán với các biến CT theo từng năm
svr_CT_2016 = SVR(C= 1, gamma= 0.1, kernel= 'rbf') 
svr_CT_2017 = SVR(C= 10, gamma= 0.001, kernel= 'rbf')
svr_CT_2018 = SVR(C= 1, gamma= 0.01, kernel= 'rbf')
svr_CT_2019 = SVR(C= 1, gamma= 0.01, kernel= 'rbf') 
svr_CT_2020 = SVR(C= 100, gamma= 0.001, kernel= 'rbf')
#Mô hình dự đoán với các biến NDVI theo từng năm
svr_NDVI_2016 = SVR(C= 10, gamma= 0.01, kernel= 'rbf')
svr_NDVI_2017 = SVR(C= 1000, gamma= 0.001, kernel= 'rbf')
svr_NDVI_2018 = SVR(C= 1000, gamma= 0.0001, kernel= 'rbf')
svr_NDVI_2019 = SVR(C= 100, gamma= 0.01, kernel= 'rbf')
svr_NDVI_2020 = SVR(C= 100, gamma= 0.01, kernel= 'rbf')
#Mô hình dự đoán với các biến NDVI và CT theo từng năm
svr_NDVI_CT_2016 = SVR(C= 100, gamma= 0.001, kernel= 'rbf')
svr_NDVI_CT_2017 = SVR(C= 1000, gamma= 0.0001, kernel= 'rbf')
svr_NDVI_CT_2018 = SVR(C= 100, gamma= 0.001, kernel= 'rbf')
svr_NDVI_CT_2019 = SVR(C= 1000, gamma= 0.0001, kernel= 'rbf')
svr_NDVI_CT_2020 = SVR(C= 100, gamma= 0.001, kernel= 'rbf')
#Mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
svr_AGR_2016 = SVR(C= 10, gamma= 0.001, kernel= 'rbf')
svr_AGR_2017 = SVR(C= 10, gamma= 0.001, kernel= 'rbf')
svr_AGR_2018 = SVR(C= 1000, gamma= 0.00001, kernel= 'rbf')
svr_AGR_2019 = SVR(C= 100, gamma= 0.001, kernel= 'rbf')
svr_AGR_2020 = SVR(C= 1000, gamma= 0.00001, kernel= 'rbf')
#Mô hình dự đoán với tất cả các biến theo từng năm
svr_ALL_2016 = SVR(C= 1000, gamma= 0.00001, kernel= 'rbf')
svr_ALL_2017 = SVR(C= 1000, gamma= 0.000001, kernel= 'rbf')
svr_ALL_2018 = SVR(C= 1000, gamma= 0.000001, kernel= 'rbf')
svr_ALL_2019 = SVR(C= 1000, gamma= 0.00001, kernel= 'rbf')
svr_ALL_2020 = SVR(C= 1000, gamma= 0.00001, kernel= 'rbf')
#Huấn luyện mô hình dự đoán với các biến CT theo từng năm
svr_CT_2016.fit(X_CT_2016_train, y_2016_train)
svr_CT_2017.fit(X_CT_2017_train, y_2017_train)
svr_CT_2018.fit(X_CT_2018_train, y_2018_train)
svr_CT_2019.fit(X_CT_2019_train, y_2019_train)
svr_CT_2020.fit(X_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI theo từng năm
svr_NDVI_2016.fit(X_NDVI_2016_train, y_2016_train)
svr_NDVI_2017.fit(X_NDVI_2017_train, y_2017_train)
svr_NDVI_2018.fit(X_NDVI_2018_train, y_2018_train)
svr_NDVI_2019.fit(X_NDVI_2019_train, y_2019_train)
svr_NDVI_2020.fit(X_NDVI_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI và CT theo từng năm
svr_NDVI_CT_2016.fit(X_NDVI_CT_2016_train, y_2016_train)
svr_NDVI_CT_2017.fit(X_NDVI_CT_2017_train, y_2017_train)
svr_NDVI_CT_2018.fit(X_NDVI_CT_2018_train, y_2018_train)
svr_NDVI_CT_2019.fit(X_NDVI_CT_2019_train, y_2019_train)
svr_NDVI_CT_2020.fit(X_NDVI_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
svr_AGR_2016.fit(X_AGR_2016_train, y_2016_train)
svr_AGR_2017.fit(X_AGR_2017_train, y_2017_train)
svr_AGR_2018.fit(X_AGR_2018_train, y_2018_train)
svr_AGR_2019.fit(X_AGR_2019_train, y_2019_train)
svr_AGR_2020.fit(X_AGR_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với tất cả các biến theo từng năm
svr_ALL_2016.fit(X_ALL_2016_train, y_2016_train)
svr_ALL_2017.fit(X_ALL_2017_train, y_2017_train)
svr_ALL_2018.fit(X_ALL_2018_train, y_2018_train)
svr_ALL_2019.fit(X_ALL_2019_train, y_2019_train)
svr_ALL_2020.fit(X_ALL_2020_train, y_2020_train)
# Out:
# SVR(C=1000, gamma=1e-05)

# %% [markdown]
# **Huấn luyện mô hình**

# %%
#Kết quả dự đoán với các biến CT
y_svr_CT_2016_pred = svr_CT_2016.predict(X_CT_2016_test)
print("Kết quả dự đoán với các biến CT năm 2016:")
print(y_svr_CT_2016_pred)
y_svr_CT_2017_pred = svr_CT_2017.predict(X_CT_2017_test)
print("\nKết quả dự đoán với các biến CT năm 2017:")
print(y_svr_CT_2017_pred)
y_svr_CT_2018_pred = svr_CT_2018.predict(X_CT_2018_test)
print("\nKết quả dự đoán với các biến CT năm 2018:")
print(y_svr_CT_2018_pred)
y_svr_CT_2019_pred = svr_CT_2019.predict(X_CT_2019_test)
print("\nKết quả dự đoán với các biến CT năm 2019:")
print(y_svr_CT_2019_pred)
y_svr_CT_2020_pred = svr_CT_2020.predict(X_CT_2020_test)
print("\nKết quả dự đoán với các biến CT năm 2020:")
print(y_svr_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_svr_NDVI_2016_pred = svr_NDVI_2016.predict(X_NDVI_2016_test)
print("\nKết quả dự đoán với các biến NDVI năm 2016:")
print(y_svr_NDVI_2016_pred)
y_svr_NDVI_2017_pred = svr_NDVI_2017.predict(X_NDVI_2017_test)
print("\nKết quả dự đoán với các biến NDVI năm 2017:")
print(y_svr_NDVI_2017_pred)
y_svr_NDVI_2018_pred = svr_NDVI_2018.predict(X_NDVI_2018_test)
print("\nKết quả dự đoán với các biến NDVI năm 2018:")
print(y_svr_NDVI_2018_pred)
y_svr_NDVI_2019_pred = svr_NDVI_2019.predict(X_NDVI_2019_test)
print("\nKết quả dự đoán với các biến NDVI năm 2019:")
print(y_svr_NDVI_2019_pred)
y_svr_NDVI_2020_pred = svr_NDVI_2020.predict(X_NDVI_2020_test)
print("\nKết quả dự đoán với các biến NDVI năm 2020:")
print(y_svr_NDVI_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_svr_NDVI_CT_2016_pred = svr_NDVI_CT_2016.predict(X_NDVI_CT_2016_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2016:")
print(y_svr_NDVI_CT_2016_pred)
y_svr_NDVI_CT_2017_pred = svr_NDVI_CT_2017.predict(X_NDVI_CT_2017_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2017:")
print(y_svr_NDVI_CT_2017_pred)
y_svr_NDVI_CT_2018_pred = svr_NDVI_CT_2018.predict(X_NDVI_CT_2018_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_svr_NDVI_CT_2018_pred)
y_svr_NDVI_CT_2019_pred = svr_NDVI_CT_2019.predict(X_NDVI_CT_2019_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_svr_NDVI_CT_2019_pred)
y_svr_NDVI_CT_2020_pred = svr_NDVI_CT_2020.predict(X_NDVI_CT_2020_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2020:")
print(y_svr_NDVI_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_svr_AGR_2016_pred = svr_AGR_2016.predict(X_AGR_2016_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2016:")
print(y_svr_AGR_2016_pred)
y_svr_AGR_2017_pred = svr_AGR_2017.predict(X_AGR_2017_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2017:")
print(y_svr_AGR_2017_pred)
y_svr_AGR_2018_pred = svr_AGR_2018.predict(X_AGR_2018_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2018:")
print(y_svr_AGR_2018_pred)
y_svr_AGR_2019_pred = svr_AGR_2019.predict(X_AGR_2019_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2019:")
print(y_svr_AGR_2019_pred)
y_svr_AGR_2020_pred = svr_AGR_2020.predict(X_AGR_2020_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2020:")
print(y_svr_AGR_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_svr_ALL_2016_pred = svr_ALL_2016.predict(X_ALL_2016_test)
print("\nKết quả dự đoán với tất cả các biến năm 2016:")
print(y_svr_ALL_2016_pred)
y_svr_ALL_2017_pred = svr_ALL_2017.predict(X_ALL_2017_test)
print("\nKết quả dự đoán với tất cả các biến năm 2017:")
print(y_svr_ALL_2017_pred)
y_svr_ALL_2018_pred = svr_ALL_2018.predict(X_ALL_2018_test)
print("\nKết quả dự đoán với tất cả các biến năm 2018:")
print(y_svr_ALL_2018_pred)
y_svr_ALL_2019_pred = svr_ALL_2019.predict(X_ALL_2019_test)
print("\nKết quả dự đoán với tất cả các biến năm 2019:")
print(y_svr_ALL_2019_pred)
y_svr_ALL_2020_pred = svr_ALL_2020.predict(X_ALL_2020_test)
print("\nKết quả dự đoán với tất cả các biến năm 2020:")
print(y_svr_ALL_2020_pred)
# Out:
# Kết quả dự đoán với các biến CT năm 2016:
# [2.10327715 2.41466939 2.54816674 2.20339759 2.79407442 2.82510383
#  1.9082415  2.66716238 1.98813307 2.75127231 2.37274859 1.92005808
#  1.93543703 2.24307704 2.87367853 2.80210705 2.45605388 2.45318925
#  2.25272547 2.9275025  1.84903816 2.3776768  2.23860347 2.25880688
#  2.64138464 2.18503912 2.4072682  1.9503581  2.19299274 1.99782706
#  2.73274648 2.18548877 2.26464387 2.52485263 3.1162258  2.56627115
#  2.37197965 2.19771619 2.5770129  2.61011795 2.42119647 2.33845825
#  3.08193536 2.1158145  2.95509086 3.26009297 2.00162981 2.34596052
#  2.56006533 2.3697896  2.45854908 2.6130597  2.22634266 2.65943402
#  2.64906664 1.7440939  2.35590558 2.13367902 3.02062926 1.60218192
#  2.08428388 1.9998057  2.08868889 2.85821959 2.17131269 2.24428729
#  2.76564894 2.79985564 2.43743589 2.56763615 2.43882441 2.3626151
#  2.92956521 2.18468668 2.82333161 2.40171485 2.47706216 1.91505885
# ...

# %% [markdown]
# **Đánh giá mô hình :**

# %% [markdown]
# Mô hình SVR dự đoán với các biến CT

# %%
from sklearn.metrics import r2_score
print("R2 score khi dự đoán với các biến CT:")

svr_CT_2016_score = r2_score(y_2016_test, y_svr_CT_2016_pred)
print("R2 score 2016: " +str(svr_CT_2016_score))

svr_CT_2017_score = r2_score(y_2017_test, y_svr_CT_2017_pred)
print("R2 score 2017: " +str(svr_CT_2017_score))

svr_CT_2018_score = r2_score(y_2018_test, y_svr_CT_2018_pred)
print("R2 score 2018: " +str(svr_CT_2018_score))

svr_CT_2019_score = r2_score(y_2019_test, y_svr_CT_2019_pred)
print("R2 score 2019: " +str(svr_CT_2019_score))

svr_CT_2020_score = r2_score(y_2020_test, y_svr_CT_2020_pred)
print("R2 score 2020: " +str(svr_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến CT:
# R2 score 2016: 0.1978815698827242
# R2 score 2017: 0.30923761801503946
# R2 score 2018: 0.4887576492630825
# R2 score 2019: 0.2956074954233109
# R2 score 2020: 0.44278820640045136

# %% [markdown]
# Mô hình SVR dự đoán với các biến NDVI

# %%
print("R2 score khi dự đoán với các biến NDVI:")

svr_NDVI_2016_score = r2_score(y_2016_test, y_svr_NDVI_2016_pred)
print("R2 score 2016: " +str(svr_NDVI_2016_score))

svr_NDVI_2017_score = r2_score(y_2017_test, y_svr_NDVI_2017_pred)
print("R2 score 2017: " +str(svr_NDVI_2017_score))

svr_NDVI_2018_score = r2_score(y_2018_test, y_svr_NDVI_2018_pred)
print("R2 score 2018: " +str(svr_NDVI_2018_score))

svr_NDVI_2019_score = r2_score(y_2019_test, y_svr_NDVI_2019_pred)
print("R2 score 2019: " +str(svr_NDVI_2019_score))

svr_NDVI_2020_score = r2_score(y_2020_test, y_svr_NDVI_2020_pred)
print("R2 score 2020: " +str(svr_NDVI_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI:
# R2 score 2016: 0.27567786247703985
# R2 score 2017: 0.22040579874951216
# R2 score 2018: 0.4970581913596933
# R2 score 2019: 0.4512305571425983
# R2 score 2020: 0.4698958186224318

# %% [markdown]
# Mô hình SVR dự đoán với các biến NDVI và các biến CT kết hợp

# %%
print("R2 score khi dự đoán với các biến NDVI và CT:")

svr_NDVI_CT_2016_score = r2_score(y_2016_test, y_svr_NDVI_CT_2016_pred)
print("R2 score 2016: " +str(svr_NDVI_CT_2016_score))

svr_NDVI_CT_2017_score = r2_score(y_2017_test, y_svr_NDVI_CT_2017_pred)
print("R2 score 2017: " +str(svr_NDVI_CT_2017_score))

svr_NDVI_CT_2018_score = r2_score(y_2018_test, y_svr_NDVI_CT_2018_pred)
print("R2 score 2018: " +str(svr_NDVI_CT_2018_score))

svr_NDVI_CT_2019_score = r2_score(y_2019_test, y_svr_NDVI_CT_2019_pred)
print("R2 score 2019: " +str(svr_NDVI_CT_2019_score))

svr_NDVI_CT_2020_score = r2_score(y_2020_test, y_svr_NDVI_CT_2020_pred)
print("R2 score 2020: " +str(svr_NDVI_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI và CT:
# R2 score 2016: 0.32876906043777565
# R2 score 2017: 0.3226634612742273
# R2 score 2018: 0.5397308333183655
# R2 score 2019: 0.4502915573164704
# R2 score 2020: 0.5472467696092154

# %% [markdown]
# Mô hình SVR dự đoán với các biến về đặc điểm nông học

# %%
print("R2 score khi dự đoán với các biến nhóm đặc điểm nông học:")

svr_AGR_2016_score = r2_score(y_2016_test, y_svr_AGR_2016_pred)
print("R2 score 2016: " +str(svr_AGR_2016_score))

svr_AGR_2017_score = r2_score(y_2017_test, y_svr_AGR_2017_pred)
print("R2 score 2017: " +str(svr_AGR_2017_score))

svr_AGR_2018_score = r2_score(y_2018_test, y_svr_AGR_2018_pred)
print("R2 score 2018: " +str(svr_AGR_2018_score))

svr_AGR_2019_score = r2_score(y_2019_test, y_svr_AGR_2019_pred)
print("R2 score 2019: " +str(svr_AGR_2019_score))

svr_AGR_2020_score = r2_score(y_2020_test, y_svr_AGR_2020_pred)
print("R2 score 2020: " +str(svr_AGR_2020_score))
# Out:
# R2 score khi dự đoán với các biến nhóm đặc điểm nông học:
# R2 score 2016: 0.4014102931392204
# R2 score 2017: 0.3494979669796451
# R2 score 2018: 0.49616559684263795
# R2 score 2019: 0.2645229372854099
# R2 score 2020: 0.44747409638112345

# %% [markdown]
# Mô hình SVR dự đoán với tất cả các biến

# %%
print("R2 score khi dự đoán với tất cả các biến:")

svr_ALL_2016_score = r2_score(y_2016_test, y_svr_ALL_2016_pred)
print("R2 score 2016: " +str(svr_ALL_2016_score))

svr_ALL_2017_score = r2_score(y_2017_test, y_svr_ALL_2017_pred)
print("R2 score 2017: " +str(svr_ALL_2017_score))

svr_ALL_2018_score = r2_score(y_2018_test, y_svr_ALL_2018_pred)
print("R2 score 2018: " +str(svr_ALL_2018_score))

svr_ALL_2019_score = r2_score(y_2019_test, y_svr_ALL_2019_pred)
print("R2 score 2019: " +str(svr_ALL_2019_score))

svr_ALL_2020_score = r2_score(y_2020_test, y_svr_ALL_2020_pred)
print("R2 score 2020: " +str(svr_ALL_2020_score))
# Out:
# R2 score khi dự đoán với tất cả các biến:
# R2 score 2016: 0.46093654511370985
# R2 score 2017: 0.4906269940752823
# R2 score 2018: 0.6059824004074386
# R2 score 2019: 0.47288915604919246
# R2 score 2020: 0.5687186240458337

# %% [markdown]
# ## Random Forest Regression Model

# %%
from sklearn.ensemble import RandomForestRegressor
#Mô hình dự đoán với các biến CT theo từng năm
rfr_CT_2016 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 116,
             verbose=2) 
rfr_CT_2017 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 133,
             verbose=2) 
rfr_CT_2018 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 116,
             verbose=2) 
rfr_CT_2019 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2) 
rfr_CT_2020 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 183,
             verbose=2)

#Mô hình dự đoán với các biến NDVI theo từng năm
rfr_NDVI_2016 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 66,
             verbose=2) 
rfr_NDVI_2017 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2) 
rfr_NDVI_2018 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 116,
             verbose=2) 
rfr_NDVI_2019 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 83,
             verbose=2) 
rfr_NDVI_2020 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)

#Mô hình dự đoán với các biến NDVI và CT theo từng năm
rfr_NDVI_CT_2016 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)
rfr_NDVI_CT_2017 = RandomForestRegressor(bootstrap = False, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 133,
             verbose=2)
rfr_NDVI_CT_2018 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 150,
             verbose=2)
rfr_NDVI_CT_2019 = RandomForestRegressor(bootstrap = False, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 183,
             verbose=2)
rfr_NDVI_CT_2020 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)


#Mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
rfr_AGR_2016 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 166,
             verbose=2)
rfr_AGR_2017 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)
rfr_AGR_2018 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 100,
             verbose=2)
rfr_AGR_2019 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 183,
             verbose=2)
rfr_AGR_2020 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 50,
             verbose=2)


#Mô hình dự đoán với tất cả các biến theo từng năm
rfr_ALL_2016 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'auto',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 166,
             verbose=2)
rfr_ALL_2017 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'auto',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 133,
             verbose=2)
rfr_ALL_2018 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'auto',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)
rfr_ALL_2019 = RandomForestRegressor(bootstrap = False, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 5,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)
rfr_ALL_2020 = RandomForestRegressor(bootstrap = True, max_depth = 15,
                         max_features = 'sqrt',
                         min_samples_leaf = 1,
                         min_samples_split = 10,
                         n_estimators = 200,
             verbose=2)


#Huấn luyện mô hình dự đoán với các biến CT theo từng năm
rfr_CT_2016.fit(X_CT_2016_train, y_2016_train)
rfr_CT_2017.fit(X_CT_2017_train, y_2017_train)
rfr_CT_2018.fit(X_CT_2018_train, y_2018_train)
rfr_CT_2019.fit(X_CT_2019_train, y_2019_train)
rfr_CT_2020.fit(X_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI theo từng năm
rfr_NDVI_2016.fit(X_NDVI_2016_train, y_2016_train)
rfr_NDVI_2017.fit(X_NDVI_2017_train, y_2017_train)
rfr_NDVI_2018.fit(X_NDVI_2018_train, y_2018_train)
rfr_NDVI_2019.fit(X_NDVI_2019_train, y_2019_train)
rfr_NDVI_2020.fit(X_NDVI_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI và CT theo từng năm
rfr_NDVI_CT_2016.fit(X_NDVI_CT_2016_train, y_2016_train)
rfr_NDVI_CT_2017.fit(X_NDVI_CT_2017_train, y_2017_train)
rfr_NDVI_CT_2018.fit(X_NDVI_CT_2018_train, y_2018_train)
rfr_NDVI_CT_2019.fit(X_NDVI_CT_2019_train, y_2019_train)
rfr_NDVI_CT_2020.fit(X_NDVI_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
rfr_AGR_2016.fit(X_AGR_2016_train, y_2016_train)
rfr_AGR_2017.fit(X_AGR_2017_train, y_2017_train)
rfr_AGR_2018.fit(X_AGR_2018_train, y_2018_train)
rfr_AGR_2019.fit(X_AGR_2019_train, y_2019_train)
rfr_AGR_2020.fit(X_AGR_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với tất cả các biến theo từng năm
rfr_ALL_2016.fit(X_ALL_2016_train, y_2016_train)
rfr_ALL_2017.fit(X_ALL_2017_train, y_2017_train)
rfr_ALL_2018.fit(X_ALL_2018_train, y_2018_train)
rfr_ALL_2019.fit(X_ALL_2019_train, y_2019_train)
rfr_ALL_2020.fit(X_ALL_2020_train, y_2020_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 116
# building tree 2 of 116
# building tree 3 of 116
# building tree 4 of 116
# building tree 5 of 116
# building tree 6 of 116
# building tree 7 of 116
# building tree 8 of 116
# building tree 9 of 116
# building tree 10 of 116
# building tree 11 of 116
# building tree 12 of 116
# building tree 13 of 116
# building tree 14 of 116
# building tree 15 of 116
# building tree 16 of 116
# building tree 17 of 116
# building tree 18 of 116
# building tree 19 of 116
# building tree 20 of 116
# building tree 21 of 116
# building tree 22 of 116
# building tree 23 of 116
# building tree 24 of 116
# building tree 25 of 116
# building tree 26 of 116
# building tree 27 of 116
# building tree 28 of 116
# building tree 29 of 116
# building tree 30 of 116
# building tree 31 of 116
# building tree 32 of 116
# ...

# %% [markdown]
# **Huấn luyện mô hình**

# %%
#Kết quả dự đoán với các biến CT
y_rfr_CT_2016_pred = rfr_CT_2016.predict(X_CT_2016_test)
print("Kết quả dự đoán với các biến CT năm 2016:")
print(y_rfr_CT_2016_pred)
y_rfr_CT_2017_pred = rfr_CT_2017.predict(X_CT_2017_test)
print("\nKết quả dự đoán với các biến CT năm 2017:")
print(y_rfr_CT_2017_pred)
y_rfr_CT_2018_pred = rfr_CT_2018.predict(X_CT_2018_test)
print("\nKết quả dự đoán với các biến CT năm 2018:")
print(y_rfr_CT_2018_pred)
y_rfr_CT_2019_pred = rfr_CT_2019.predict(X_CT_2019_test)
print("\nKết quả dự đoán với các biến CT năm 2019:")
print(y_rfr_CT_2019_pred)
y_rfr_CT_2020_pred = rfr_CT_2020.predict(X_CT_2020_test)
print("\nKết quả dự đoán với các biến CT năm 2020:")
print(y_rfr_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_rfr_NDVI_2016_pred = rfr_NDVI_2016.predict(X_NDVI_2016_test)
print("\nKết quả dự đoán với các biến NDVI năm 2016:")
print(y_rfr_NDVI_2016_pred)
y_rfr_NDVI_2017_pred = rfr_NDVI_2017.predict(X_NDVI_2017_test)
print("\nKết quả dự đoán với các biến NDVI năm 2017:")
print(y_rfr_NDVI_2017_pred)
y_rfr_NDVI_2018_pred = rfr_NDVI_2018.predict(X_NDVI_2018_test)
print("\nKết quả dự đoán với các biến NDVI năm 2018:")
print(y_rfr_NDVI_2018_pred)
y_rfr_NDVI_2019_pred = rfr_NDVI_2019.predict(X_NDVI_2019_test)
print("\nKết quả dự đoán với các biến NDVI năm 2019:")
print(y_rfr_NDVI_2019_pred)
y_rfr_NDVI_2020_pred = rfr_NDVI_2020.predict(X_NDVI_2020_test)
print("\nKết quả dự đoán với các biến NDVI năm 2020:")
print(y_rfr_NDVI_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_rfr_NDVI_CT_2016_pred = rfr_NDVI_CT_2016.predict(X_NDVI_CT_2016_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2016:")
print(y_rfr_NDVI_CT_2016_pred)
y_rfr_NDVI_CT_2017_pred = rfr_NDVI_CT_2017.predict(X_NDVI_CT_2017_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2017:")
print(y_rfr_NDVI_CT_2017_pred)
y_rfr_NDVI_CT_2018_pred = rfr_NDVI_CT_2018.predict(X_NDVI_CT_2018_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_rfr_NDVI_CT_2018_pred)
y_rfr_NDVI_CT_2019_pred = rfr_NDVI_CT_2019.predict(X_NDVI_CT_2019_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_rfr_NDVI_CT_2019_pred)
y_rfr_NDVI_CT_2020_pred = rfr_NDVI_CT_2020.predict(X_NDVI_CT_2020_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2020:")
print(y_rfr_NDVI_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_rfr_AGR_2016_pred = rfr_AGR_2016.predict(X_AGR_2016_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2016:")
print(y_rfr_AGR_2016_pred)
y_rfr_AGR_2017_pred = rfr_AGR_2017.predict(X_AGR_2017_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2017:")
print(y_rfr_AGR_2017_pred)
y_rfr_AGR_2018_pred = rfr_AGR_2018.predict(X_AGR_2018_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2018:")
print(y_rfr_AGR_2018_pred)
y_rfr_AGR_2019_pred = rfr_AGR_2019.predict(X_AGR_2019_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2019:")
print(y_rfr_AGR_2019_pred)
y_rfr_AGR_2020_pred = rfr_AGR_2020.predict(X_AGR_2020_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2020:")
print(y_rfr_AGR_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_rfr_ALL_2016_pred = rfr_ALL_2016.predict(X_ALL_2016_test)
print("\nKết quả dự đoán với tất cả các biến năm 2016:")
print(y_rfr_ALL_2016_pred)
y_rfr_ALL_2017_pred = rfr_ALL_2017.predict(X_ALL_2017_test)
print("\nKết quả dự đoán với tất cả các biến năm 2017:")
print(y_rfr_ALL_2017_pred)
y_rfr_ALL_2018_pred = rfr_ALL_2018.predict(X_ALL_2018_test)
print("\nKết quả dự đoán với tất cả các biến năm 2018:")
print(y_rfr_ALL_2018_pred)
y_rfr_ALL_2019_pred = rfr_ALL_2019.predict(X_ALL_2019_test)
print("\nKết quả dự đoán với tất cả các biến năm 2019:")
print(y_rfr_ALL_2019_pred)
y_rfr_ALL_2020_pred = rfr_ALL_2020.predict(X_ALL_2020_test)
print("\nKết quả dự đoán với tất cả các biến năm 2020:")
print(y_rfr_ALL_2020_pred)
# Out:
# Kết quả dự đoán với các biến CT năm 2016:
# [2.19181417 2.49392801 2.41212505 2.39714871 2.70298095 2.69561981
#  2.19004947 2.53875786 2.20162784 2.67974313 2.28329161 1.98976064
#  2.20778786 2.56331933 2.4616185  2.78246909 2.48673263 2.28248747
#  2.33237041 2.68539306 2.00011315 2.54456464 2.3468133  2.31678588
#  2.67416648 2.30307166 2.30861894 2.20564346 2.31775884 2.21463349
#  2.58502309 2.08281003 2.40660433 2.44968339 2.65703795 2.10951022
#  2.26637846 2.07768158 2.49808302 2.75269636 2.52424363 2.56980147
#  2.84956303 2.14736869 2.85971568 2.96596054 2.44670423 2.45761162
#  2.40137114 2.59150695 2.56357426 2.54673607 2.30278036 2.53706144
#  2.77650256 2.0497538  2.1786142  2.40450341 2.87953974 1.92248265
#  2.1967036  2.19671493 2.25425016 2.95306096 2.2772961  2.46702989
#  2.78681086 2.60630376 2.65105279 2.72995292 2.53260074 2.44957491
#  2.73686401 2.35420551 2.52274161 2.53940533 2.59190463 2.24667045
# ...

# %% [markdown]
# **Đánh giá mô hình**

# %% [markdown]
# Mô hình RFR dự đoán với các biến CT

# %%
print("R2 score khi dự đoán với các biến CT:")

rfr_CT_2016_score = r2_score(y_2016_test, y_rfr_CT_2016_pred)
print("R2 score 2016: " +str(rfr_CT_2016_score))

rfr_CT_2017_score = r2_score(y_2017_test, y_rfr_CT_2017_pred)
print("R2 score 2017: " +str(rfr_CT_2017_score))

rfr_CT_2018_score = r2_score(y_2018_test, y_rfr_CT_2018_pred)
print("R2 score 2018: " +str(rfr_CT_2018_score))

rfr_CT_2019_score = r2_score(y_2019_test, y_rfr_CT_2019_pred)
print("R2 score 2019: " +str(rfr_CT_2019_score))

rfr_CT_2020_score = r2_score(y_2020_test, y_rfr_CT_2020_pred)
print("R2 score 2020: " +str(rfr_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến CT:
# R2 score 2016: 0.2047525328354981
# R2 score 2017: 0.27441883997103433
# R2 score 2018: 0.5004306447825784
# R2 score 2019: 0.32694556606222236
# R2 score 2020: 0.431960814614782

# %% [markdown]
# Mô hình RFR dự đoán với các biến NDVI

# %%
print("R2 score khi dự đoán với các biến NDVI:")

rfr_NDVI_2016_score = r2_score(y_2016_test, y_rfr_NDVI_2016_pred)
print("R2 score 2016: " +str(rfr_NDVI_2016_score))

rfr_NDVI_2017_score = r2_score(y_2017_test, y_rfr_NDVI_2017_pred)
print("R2 score 2017: " +str(rfr_NDVI_2017_score))

rfr_NDVI_2018_score = r2_score(y_2018_test, y_rfr_NDVI_2018_pred)
print("R2 score 2018: " +str(rfr_NDVI_2018_score))

rfr_NDVI_2019_score = r2_score(y_2019_test, y_rfr_NDVI_2019_pred)
print("R2 score 2019: " +str(rfr_NDVI_2019_score))

rfr_NDVI_2020_score = r2_score(y_2020_test, y_rfr_NDVI_2020_pred)
print("R2 score 2020: " +str(rfr_NDVI_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI:
# R2 score 2016: 0.2917703741134716
# R2 score 2017: 0.25635548579997447
# R2 score 2018: 0.49362267527785786
# R2 score 2019: 0.4701864348294865
# R2 score 2020: 0.4662550520527091

# %% [markdown]
# Mô hình RFR dự đoán với các biến NDVI và các biến CT kết hợp

# %%
print("R2 score khi dự đoán với các biến NDVI và CT:")

rfr_NDVI_CT_2016_score = r2_score(y_2016_test, y_rfr_NDVI_CT_2016_pred)
print("R2 score 2016: " +str(rfr_NDVI_CT_2016_score))

rfr_NDVI_CT_2017_score = r2_score(y_2017_test, y_rfr_NDVI_CT_2017_pred)
print("R2 score 2017: " +str(rfr_NDVI_CT_2017_score))

rfr_NDVI_CT_2018_score = r2_score(y_2018_test, y_rfr_NDVI_CT_2018_pred)
print("R2 score 2018: " +str(rfr_NDVI_CT_2018_score))

rfr_NDVI_CT_2019_score = r2_score(y_2019_test, y_rfr_NDVI_CT_2019_pred)
print("R2 score 2019: " +str(rfr_NDVI_CT_2019_score))

rfr_NDVI_CT_2020_score = r2_score(y_2020_test, y_rfr_NDVI_CT_2020_pred)
print("R2 score 2020: " +str(rfr_NDVI_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI và CT:
# R2 score 2016: 0.38411773428399176
# R2 score 2017: 0.32429501836872054
# R2 score 2018: 0.5491660630198738
# R2 score 2019: 0.49387927212615246
# R2 score 2020: 0.5172813167560957

# %% [markdown]
# Mô hình RFR dự đoán với các biến về đặc điểm nông học

# %%
print("R2 score khi dự đoán với các biến nhóm đặc điểm nông học:")

rfr_AGR_2016_score = r2_score(y_2016_test, y_rfr_AGR_2016_pred)
print("R2 score 2016: " +str(rfr_AGR_2016_score))

rfr_AGR_2017_score = r2_score(y_2017_test, y_rfr_AGR_2017_pred)
print("R2 score 2017: " +str(rfr_AGR_2017_score))

rfr_AGR_2018_score = r2_score(y_2018_test, y_rfr_AGR_2018_pred)
print("R2 score 2018: " +str(rfr_AGR_2018_score))

rfr_AGR_2019_score = r2_score(y_2019_test, y_rfr_AGR_2019_pred)
print("R2 score 2019: " +str(rfr_AGR_2019_score))

rfr_AGR_2020_score = r2_score(y_2020_test, y_rfr_AGR_2020_pred)
print("R2 score 2020: " +str(rfr_AGR_2020_score))
# Out:
# R2 score khi dự đoán với các biến nhóm đặc điểm nông học:
# R2 score 2016: 0.35176860273681776
# R2 score 2017: 0.34497988011784764
# R2 score 2018: 0.43512769642231897
# R2 score 2019: 0.26013141331370015
# R2 score 2020: 0.3567845464106414

# %% [markdown]
# Mô hình RFR dự đoán với tất cả các biến

# %%
print("R2 score khi dự đoán với tất cả các biến:")

rfr_ALL_2016_score = r2_score(y_2016_test, y_rfr_ALL_2016_pred)
print("R2 score 2016: " +str(rfr_ALL_2016_score))

rfr_ALL_2017_score = r2_score(y_2017_test, y_rfr_ALL_2017_pred)
print("R2 score 2017: " +str(rfr_ALL_2017_score))

rfr_ALL_2018_score = r2_score(y_2018_test, y_rfr_ALL_2018_pred)
print("R2 score 2018: " +str(rfr_ALL_2018_score))

rfr_ALL_2019_score = r2_score(y_2019_test, y_rfr_ALL_2019_pred)
print("R2 score 2019: " +str(rfr_ALL_2019_score))

rfr_ALL_2020_score = r2_score(y_2020_test, y_rfr_ALL_2020_pred)
print("R2 score 2020: " +str(rfr_ALL_2020_score))
# Out:
# R2 score khi dự đoán với tất cả các biến:
# R2 score 2016: 0.47734546626416907
# R2 score 2017: 0.4663307845325966
# R2 score 2018: 0.61168693796985
# R2 score 2019: 0.5150008447525409
# R2 score 2020: 0.5603196443854537

# %% [markdown]
# ## Ridge Regression Model

# %%
from sklearn.linear_model import Ridge

# %%
#Mô hình dự đoán với các biến CT theo từng năm
ridge_CT_2016 = Ridge(alpha=50) 
ridge_CT_2017 = Ridge(alpha=100) 
ridge_CT_2018 = Ridge(alpha=100) 
ridge_CT_2019 = Ridge(alpha=100) 
ridge_CT_2020 = Ridge(alpha=100)
#Mô hình dự đoán với các biến NDVI theo từng năm
ridge_NDVI_2016 = Ridge(alpha=0.01) 
ridge_NDVI_2017 = Ridge(alpha=1) 
ridge_NDVI_2018 = Ridge(alpha=1) 
ridge_NDVI_2019 = Ridge(alpha=0.01) 
ridge_NDVI_2020 = Ridge(alpha=0.01)
#Mô hình dự đoán với các biến NDVI và CT theo từng năm
ridge_NDVI_CT_2016 = Ridge(alpha=0.01)
ridge_NDVI_CT_2017 = Ridge(alpha=1)
ridge_NDVI_CT_2018 = Ridge(alpha=1)
ridge_NDVI_CT_2019 = Ridge(alpha=0.01)
ridge_NDVI_CT_2020 = Ridge(alpha=0.01)
#Mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
ridge_AGR_2016 = Ridge(alpha=20)
ridge_AGR_2017 = Ridge(alpha=1)
ridge_AGR_2018 = Ridge(alpha=1e-15)
ridge_AGR_2019 = Ridge(alpha=5)
ridge_AGR_2020 = Ridge(alpha=10)
#Mô hình dự đoán với tất cả các biến theo từng năm
ridge_ALL_2016 = Ridge(alpha=0.01)
ridge_ALL_2017 = Ridge(alpha=1)
ridge_ALL_2018 = Ridge(alpha=1)
ridge_ALL_2019 = Ridge(alpha=0.01)
ridge_ALL_2020 = Ridge(alpha=1)
#Huấn luyện mô hình dự đoán với các biến CT theo từng năm
ridge_CT_2016.fit(X_CT_2016_train, y_2016_train)
ridge_CT_2017.fit(X_CT_2017_train, y_2017_train)
ridge_CT_2018.fit(X_CT_2018_train, y_2018_train)
ridge_CT_2019.fit(X_CT_2019_train, y_2019_train)
ridge_CT_2020.fit(X_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI theo từng năm
ridge_NDVI_2016.fit(X_NDVI_2016_train, y_2016_train)
ridge_NDVI_2017.fit(X_NDVI_2017_train, y_2017_train)
ridge_NDVI_2018.fit(X_NDVI_2018_train, y_2018_train)
ridge_NDVI_2019.fit(X_NDVI_2019_train, y_2019_train)
ridge_NDVI_2020.fit(X_NDVI_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI và CT theo từng năm
ridge_NDVI_CT_2016.fit(X_NDVI_CT_2016_train, y_2016_train)
ridge_NDVI_CT_2017.fit(X_NDVI_CT_2017_train, y_2017_train)
ridge_NDVI_CT_2018.fit(X_NDVI_CT_2018_train, y_2018_train)
ridge_NDVI_CT_2019.fit(X_NDVI_CT_2019_train, y_2019_train)
ridge_NDVI_CT_2020.fit(X_NDVI_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
ridge_AGR_2016.fit(X_AGR_2016_train, y_2016_train)
ridge_AGR_2017.fit(X_AGR_2017_train, y_2017_train)
ridge_AGR_2018.fit(X_AGR_2018_train, y_2018_train)
ridge_AGR_2019.fit(X_AGR_2019_train, y_2019_train)
ridge_AGR_2020.fit(X_AGR_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với tất cả các biến theo từng năm
ridge_ALL_2016.fit(X_ALL_2016_train, y_2016_train)
ridge_ALL_2017.fit(X_ALL_2017_train, y_2017_train)
ridge_ALL_2018.fit(X_ALL_2018_train, y_2018_train)
ridge_ALL_2019.fit(X_ALL_2019_train, y_2019_train)
ridge_ALL_2020.fit(X_ALL_2020_train, y_2020_train)
# Out:
# Ridge(alpha=1)

# %% [markdown]
# **Huấn luyện mô hình**

# %%
#Kết quả dự đoán với các biến CT
y_ridge_CT_2016_pred = ridge_CT_2016.predict(X_CT_2016_test)
print("Kết quả dự đoán với các biến CT năm 2016:")
print(y_ridge_CT_2016_pred)
y_ridge_CT_2017_pred = ridge_CT_2017.predict(X_CT_2017_test)
print("\nKết quả dự đoán với các biến CT năm 2017:")
print(y_ridge_CT_2017_pred)
y_ridge_CT_2018_pred = ridge_CT_2018.predict(X_CT_2018_test)
print("\nKết quả dự đoán với các biến CT năm 2018:")
print(y_ridge_CT_2018_pred)
y_ridge_CT_2019_pred = ridge_CT_2019.predict(X_CT_2019_test)
print("\nKết quả dự đoán với các biến CT năm 2019:")
print(y_ridge_CT_2019_pred)
y_ridge_CT_2020_pred = ridge_CT_2020.predict(X_CT_2020_test)
print("\nKết quả dự đoán với các biến CT năm 2020:")
print(y_ridge_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_ridge_NDVI_2016_pred = ridge_NDVI_2016.predict(X_NDVI_2016_test)
print("\nKết quả dự đoán với các biến NDVI năm 2016:")
print(y_ridge_NDVI_2016_pred)
y_ridge_NDVI_2017_pred = ridge_NDVI_2017.predict(X_NDVI_2017_test)
print("\nKết quả dự đoán với các biến NDVI năm 2017:")
print(y_ridge_NDVI_2017_pred)
y_ridge_NDVI_2018_pred = ridge_NDVI_2018.predict(X_NDVI_2018_test)
print("\nKết quả dự đoán với các biến NDVI năm 2018:")
print(y_ridge_NDVI_2018_pred)
y_ridge_NDVI_2019_pred = ridge_NDVI_2019.predict(X_NDVI_2019_test)
print("\nKết quả dự đoán với các biến NDVI năm 2019:")
print(y_ridge_NDVI_2019_pred)
y_ridge_NDVI_2020_pred = ridge_NDVI_2020.predict(X_NDVI_2020_test)
print("\nKết quả dự đoán với các biến NDVI năm 2020:")
print(y_ridge_NDVI_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_ridge_NDVI_CT_2016_pred = ridge_NDVI_CT_2016.predict(X_NDVI_CT_2016_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2016:")
print(y_ridge_NDVI_CT_2016_pred)
y_ridge_NDVI_CT_2017_pred = ridge_NDVI_CT_2017.predict(X_NDVI_CT_2017_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2017:")
print(y_ridge_NDVI_CT_2017_pred)
y_ridge_NDVI_CT_2018_pred = ridge_NDVI_CT_2018.predict(X_NDVI_CT_2018_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_ridge_NDVI_CT_2018_pred)
y_ridge_NDVI_CT_2019_pred = ridge_NDVI_CT_2019.predict(X_NDVI_CT_2019_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_ridge_NDVI_CT_2019_pred)
y_ridge_NDVI_CT_2020_pred = ridge_NDVI_CT_2020.predict(X_NDVI_CT_2020_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2020:")
print(y_ridge_NDVI_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_ridge_AGR_2016_pred = ridge_AGR_2016.predict(X_AGR_2016_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2016:")
print(y_ridge_AGR_2016_pred)
y_ridge_AGR_2017_pred = ridge_AGR_2017.predict(X_AGR_2017_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2017:")
print(y_ridge_AGR_2017_pred)
y_ridge_AGR_2018_pred = ridge_AGR_2018.predict(X_AGR_2018_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2018:")
print(y_ridge_AGR_2018_pred)
y_ridge_AGR_2019_pred = ridge_AGR_2019.predict(X_AGR_2019_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2019:")
print(y_ridge_AGR_2019_pred)
y_ridge_AGR_2020_pred = ridge_AGR_2020.predict(X_AGR_2020_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2020:")
print(y_ridge_AGR_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_ridge_ALL_2016_pred = ridge_ALL_2016.predict(X_ALL_2016_test)
print("\nKết quả dự đoán với tất cả các biến năm 2016:")
print(y_ridge_ALL_2016_pred)
y_ridge_ALL_2017_pred = ridge_ALL_2017.predict(X_ALL_2017_test)
print("\nKết quả dự đoán với tất cả các biến năm 2017:")
print(y_ridge_ALL_2017_pred)
y_ridge_ALL_2018_pred = ridge_ALL_2018.predict(X_ALL_2018_test)
print("\nKết quả dự đoán với tất cả các biến năm 2018:")
print(y_ridge_ALL_2018_pred)
y_ridge_ALL_2019_pred = ridge_ALL_2019.predict(X_ALL_2019_test)
print("\nKết quả dự đoán với tất cả các biến năm 2019:")
print(y_ridge_ALL_2019_pred)
y_ridge_ALL_2020_pred = ridge_ALL_2020.predict(X_ALL_2020_test)
print("\nKết quả dự đoán với tất cả các biến năm 2020:")
print(y_ridge_ALL_2020_pred)
# Out:
# Kết quả dự đoán với các biến CT năm 2016:
# [2.39570959 2.29514773 2.50893547 2.36760002 2.40450472 2.64962085
#  2.33924089 2.72389521 2.22714311 2.67589814 2.10688378 2.02436831
#  2.19326933 2.21281169 2.4930003  2.4396078  2.15563593 2.55079078
#  2.4670524  2.64194931 2.07265174 2.61910235 2.10901985 2.34688015
#  2.8417569  2.43993111 2.31316208 2.44152938 2.16946121 2.25565359
#  2.99377067 2.3846857  2.533626   2.30930928 2.58686884 1.72530561
#  2.45089066 2.0373419  2.44881681 2.39215322 2.57402198 2.58028616
#  2.54025847 2.2352148  2.52824418 2.68499966 2.35178511 2.45722189
#  2.48354353 2.56293298 2.58425063 2.5748861  2.39934619 2.85577133
#  2.76703765 2.27745968 2.3617525  2.37513459 2.79254683 2.11257443
#  2.37287055 2.39003578 2.2582345  2.78858943 2.04920878 2.58095557
#  2.55941279 2.45849476 2.68589209 2.76727706 2.29701302 2.49157275
#  2.70882064 2.5293738  2.54591305 2.84197784 2.59979995 2.24803547
# ...

# %% [markdown]
# **Đánh giá mô hình**

# %% [markdown]
# Mô hình Ridge dự đoán với các biến CT

# %%
print("R2 score khi dự đoán với các biến CT:")

ridge_CT_2016_score = r2_score(y_2016_test, y_ridge_CT_2016_pred)
print("R2 score 2016: " +str(ridge_CT_2016_score))

ridge_CT_2017_score = r2_score(y_2017_test, y_ridge_CT_2017_pred)
print("R2 score 2017: " +str(ridge_CT_2017_score))

ridge_CT_2018_score = r2_score(y_2018_test, y_ridge_CT_2018_pred)
print("R2 score 2018: " +str(ridge_CT_2018_score))

ridge_CT_2019_score = r2_score(y_2019_test, y_ridge_CT_2019_pred)
print("R2 score 2019: " +str(ridge_CT_2019_score))

ridge_CT_2020_score = r2_score(y_2020_test, y_ridge_CT_2020_pred)
print("R2 score 2020: " +str(ridge_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến CT:
# R2 score 2016: 0.09635267299055839
# R2 score 2017: 0.28736306992948724
# R2 score 2018: 0.45034966406097265
# R2 score 2019: 0.2804503455737537
# R2 score 2020: 0.3935325816964501

# %% [markdown]
# Mô hình Ridge dự đoán với các biến NDVI

# %%
print("R2 score khi dự đoán với các biến NDVI:")

ridge_NDVI_2016_score = r2_score(y_2016_test, y_ridge_NDVI_2016_pred)
print("R2 score 2016: " +str(ridge_NDVI_2016_score))

ridge_NDVI_2017_score = r2_score(y_2017_test, y_ridge_NDVI_2017_pred)
print("R2 score 2017: " +str(ridge_NDVI_2017_score))

ridge_NDVI_2018_score = r2_score(y_2018_test, y_ridge_NDVI_2018_pred)
print("R2 score 2018: " +str(ridge_NDVI_2018_score))

ridge_NDVI_2019_score = r2_score(y_2019_test, y_ridge_NDVI_2019_pred)
print("R2 score 2019: " +str(ridge_NDVI_2019_score))

ridge_NDVI_2020_score = r2_score(y_2020_test, y_ridge_NDVI_2020_pred)
print("R2 score 2020: " +str(ridge_NDVI_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI:
# R2 score 2016: 0.2913457844487709
# R2 score 2017: 0.19728360331811412
# R2 score 2018: 0.5096945351847288
# R2 score 2019: 0.46805882941148824
# R2 score 2020: 0.46733118644296845

# %% [markdown]
# Mô hình Ridge dự đoán với các biến NDVI và các biến CT kết hợp

# %%
print("R2 score khi dự đoán với các biến NDVI và CT:")

ridge_NDVI_CT_2016_score = r2_score(y_2016_test, y_ridge_NDVI_CT_2016_pred)
print("R2 score 2016: " +str(ridge_NDVI_CT_2016_score))

ridge_NDVI_CT_2017_score = r2_score(y_2017_test, y_ridge_NDVI_CT_2017_pred)
print("R2 score 2017: " +str(ridge_NDVI_CT_2017_score))

ridge_NDVI_CT_2018_score = r2_score(y_2018_test, y_ridge_NDVI_CT_2018_pred)
print("R2 score 2018: " +str(ridge_NDVI_CT_2018_score))

ridge_NDVI_CT_2019_score = r2_score(y_2019_test, y_ridge_NDVI_CT_2019_pred)
print("R2 score 2019: " +str(ridge_NDVI_CT_2019_score))

ridge_NDVI_CT_2020_score = r2_score(y_2020_test, y_ridge_NDVI_CT_2020_pred)
print("R2 score 2020: " +str(ridge_NDVI_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI và CT:
# R2 score 2016: 0.3154727787803525
# R2 score 2017: 0.30482685139354027
# R2 score 2018: 0.5481749040598148
# R2 score 2019: 0.47195626684153036
# R2 score 2020: 0.5266683754127556

# %% [markdown]
# Mô hình Ridge dự đoán với các biến về đặc điểm nông học

# %%
print("R2 score khi dự đoán với các biến nhóm đặc điểm nông học:")

ridge_AGR_2016_score = r2_score(y_2016_test, y_ridge_AGR_2016_pred)
print("R2 score 2016: " +str(ridge_AGR_2016_score))

ridge_AGR_2017_score = r2_score(y_2017_test, y_ridge_AGR_2017_pred)
print("R2 score 2017: " +str(ridge_AGR_2017_score))

ridge_AGR_2018_score = r2_score(y_2018_test, y_ridge_AGR_2018_pred)
print("R2 score 2018: " +str(ridge_AGR_2018_score))

ridge_AGR_2019_score = r2_score(y_2019_test, y_ridge_AGR_2019_pred)
print("R2 score 2019: " +str(ridge_AGR_2019_score))

ridge_AGR_2020_score = r2_score(y_2020_test, y_ridge_AGR_2020_pred)
print("R2 score 2020: " +str(ridge_AGR_2020_score))
# Out:
# R2 score khi dự đoán với các biến nhóm đặc điểm nông học:
# R2 score 2016: 0.37987631168266633
# R2 score 2017: 0.3126350697439232
# R2 score 2018: 0.490477061835764
# R2 score 2019: 0.2567745143118435
# R2 score 2020: 0.4328180445926536

# %% [markdown]
# Mô hình Ridge dự đoán với tất cả các biến

# %%
print("R2 score khi dự đoán với tất cả các biến:")

ridge_ALL_2016_score = r2_score(y_2016_test, y_ridge_ALL_2016_pred)
print("R2 score 2016: " +str(ridge_ALL_2016_score))

ridge_ALL_2017_score = r2_score(y_2017_test, y_ridge_ALL_2017_pred)
print("R2 score 2017: " +str(ridge_ALL_2017_score))

ridge_ALL_2018_score = r2_score(y_2018_test, y_ridge_ALL_2018_pred)
print("R2 score 2018: " +str(ridge_ALL_2018_score))

ridge_ALL_2019_score = r2_score(y_2019_test, y_ridge_ALL_2019_pred)
print("R2 score 2019: " +str(ridge_ALL_2019_score))

ridge_ALL_2020_score = r2_score(y_2020_test, y_ridge_ALL_2020_pred)
print("R2 score 2020: " +str(ridge_ALL_2020_score))
# Out:
# R2 score khi dự đoán với tất cả các biến:
# R2 score 2016: 0.4934379025833219
# R2 score 2017: 0.49805168680682677
# R2 score 2018: 0.6339456882307714
# R2 score 2019: 0.529558195435889
# R2 score 2020: 0.6278173377812308

# %% [markdown]
# ## Lasso Regression Model

# %%
from sklearn.linear_model import Lasso
#Mô hình dự đoán với các biến CT theo từng năm
lasso_CT_2016 = Lasso(alpha=1e-08) 
lasso_CT_2017 = Lasso(alpha=0.01) 
lasso_CT_2018 = Lasso(alpha=0.001) 
lasso_CT_2019 = Lasso(alpha=1e-15) 
lasso_CT_2020 = Lasso(alpha=0.01)
#Mô hình dự đoán với các biến NDVI theo từng năm
lasso_NDVI_2016 = Lasso(alpha=0.001) 
lasso_NDVI_2017 = Lasso(alpha=0.001) 
lasso_NDVI_2018 = Lasso(alpha=0.001) 
lasso_NDVI_2019 = Lasso(alpha=1e-08) 
lasso_NDVI_2020 = Lasso(alpha=1e-15)
#Mô hình dự đoán với các biến NDVI và CT theo từng năm
lasso_NDVI_CT_2016 = Lasso(alpha=1e-08)
lasso_NDVI_CT_2017 = Lasso(alpha=0.001)
lasso_NDVI_CT_2018 = Lasso(alpha=0.001)
lasso_NDVI_CT_2019 = Lasso(alpha=0.001)
lasso_NDVI_CT_2020 = Lasso(alpha=1e-08)
#Mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
lasso_AGR_2016 = Lasso(alpha=0.001)
lasso_AGR_2017 = Lasso(alpha=0.001)
lasso_AGR_2018 = Lasso(alpha=0.001)
lasso_AGR_2019 = Lasso(alpha=1e-08)
lasso_AGR_2020 = Lasso(alpha=0.01)
#Mô hình dự đoán với tất cả các biến theo từng năm
lasso_ALL_2016 = Lasso(alpha=0.001)
lasso_ALL_2017 = Lasso(alpha=0.001)
lasso_ALL_2018 = Lasso(alpha=0.001)
lasso_ALL_2019 = Lasso(alpha=0.001)
lasso_ALL_2020 = Lasso(alpha=0.001)
#Huấn luyện mô hình dự đoán với các biến CT theo từng năm
lasso_CT_2016.fit(X_CT_2016_train, y_2016_train)
lasso_CT_2017.fit(X_CT_2017_train, y_2017_train)
lasso_CT_2018.fit(X_CT_2018_train, y_2018_train)
lasso_CT_2019.fit(X_CT_2019_train, y_2019_train)
lasso_CT_2020.fit(X_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI theo từng năm
lasso_NDVI_2016.fit(X_NDVI_2016_train, y_2016_train)
lasso_NDVI_2017.fit(X_NDVI_2017_train, y_2017_train)
lasso_NDVI_2018.fit(X_NDVI_2018_train, y_2018_train)
lasso_NDVI_2019.fit(X_NDVI_2019_train, y_2019_train)
lasso_NDVI_2020.fit(X_NDVI_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI và CT theo từng năm
lasso_NDVI_CT_2016.fit(X_NDVI_CT_2016_train, y_2016_train)
lasso_NDVI_CT_2017.fit(X_NDVI_CT_2017_train, y_2017_train)
lasso_NDVI_CT_2018.fit(X_NDVI_CT_2018_train, y_2018_train)
lasso_NDVI_CT_2019.fit(X_NDVI_CT_2019_train, y_2019_train)
lasso_NDVI_CT_2020.fit(X_NDVI_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
lasso_AGR_2016.fit(X_AGR_2016_train, y_2016_train)
lasso_AGR_2017.fit(X_AGR_2017_train, y_2017_train)
lasso_AGR_2018.fit(X_AGR_2018_train, y_2018_train)
lasso_AGR_2019.fit(X_AGR_2019_train, y_2019_train)
lasso_AGR_2020.fit(X_AGR_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với tất cả các biến theo từng năm
lasso_ALL_2016.fit(X_ALL_2016_train, y_2016_train)
lasso_ALL_2017.fit(X_ALL_2017_train, y_2017_train)
lasso_ALL_2018.fit(X_ALL_2018_train, y_2018_train)
lasso_ALL_2019.fit(X_ALL_2019_train, y_2019_train)
lasso_ALL_2020.fit(X_ALL_2020_train, y_2020_train)
# Out:
# Lasso(alpha=0.001)

# %% [markdown]
# **Huấn luyện mô hình**

# %%
#Kết quả dự đoán với các biến CT
y_lasso_CT_2016_pred = lasso_CT_2016.predict(X_CT_2016_test)
print("Kết quả dự đoán với các biến CT năm 2016:")
print(y_lasso_CT_2016_pred)
y_lasso_CT_2017_pred = lasso_CT_2017.predict(X_CT_2017_test)
print("\nKết quả dự đoán với các biến CT năm 2017:")
print(y_lasso_CT_2017_pred)
y_lasso_CT_2018_pred = lasso_CT_2018.predict(X_CT_2018_test)
print("\nKết quả dự đoán với các biến CT năm 2018:")
print(y_lasso_CT_2018_pred)
y_lasso_CT_2019_pred = lasso_CT_2019.predict(X_CT_2019_test)
print("\nKết quả dự đoán với các biến CT năm 2019:")
print(y_lasso_CT_2019_pred)
y_lasso_CT_2020_pred = lasso_CT_2020.predict(X_CT_2020_test)
print("\nKết quả dự đoán với các biến CT năm 2020:")
print(y_lasso_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_lasso_NDVI_2016_pred = lasso_NDVI_2016.predict(X_NDVI_2016_test)
print("\nKết quả dự đoán với các biến NDVI năm 2016:")
print(y_lasso_NDVI_2016_pred)
y_lasso_NDVI_2017_pred = lasso_NDVI_2017.predict(X_NDVI_2017_test)
print("\nKết quả dự đoán với các biến NDVI năm 2017:")
print(y_lasso_NDVI_2017_pred)
y_lasso_NDVI_2018_pred = lasso_NDVI_2018.predict(X_NDVI_2018_test)
print("\nKết quả dự đoán với các biến NDVI năm 2018:")
print(y_lasso_NDVI_2018_pred)
y_lasso_NDVI_2019_pred = lasso_NDVI_2019.predict(X_NDVI_2019_test)
print("\nKết quả dự đoán với các biến NDVI năm 2019:")
print(y_lasso_NDVI_2019_pred)
y_lasso_NDVI_2020_pred = lasso_NDVI_2020.predict(X_NDVI_2020_test)
print("\nKết quả dự đoán với các biến NDVI năm 2020:")
print(y_lasso_NDVI_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_lasso_NDVI_CT_2016_pred = lasso_NDVI_CT_2016.predict(X_NDVI_CT_2016_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2016:")
print(y_lasso_NDVI_CT_2016_pred)
y_lasso_NDVI_CT_2017_pred = lasso_NDVI_CT_2017.predict(X_NDVI_CT_2017_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2017:")
print(y_lasso_NDVI_CT_2017_pred)
y_lasso_NDVI_CT_2018_pred = lasso_NDVI_CT_2018.predict(X_NDVI_CT_2018_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_lasso_NDVI_CT_2018_pred)
y_lasso_NDVI_CT_2019_pred = lasso_NDVI_CT_2019.predict(X_NDVI_CT_2019_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_lasso_NDVI_CT_2019_pred)
y_lasso_NDVI_CT_2020_pred = lasso_NDVI_CT_2020.predict(X_NDVI_CT_2020_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2020:")
print(y_lasso_NDVI_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_lasso_AGR_2016_pred = lasso_AGR_2016.predict(X_AGR_2016_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2016:")
print(y_lasso_AGR_2016_pred)
y_lasso_AGR_2017_pred = lasso_AGR_2017.predict(X_AGR_2017_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2017:")
print(y_lasso_AGR_2017_pred)
y_lasso_AGR_2018_pred = lasso_AGR_2018.predict(X_AGR_2018_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2018:")
print(y_lasso_AGR_2018_pred)
y_lasso_AGR_2019_pred = lasso_AGR_2019.predict(X_AGR_2019_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2019:")
print(y_lasso_AGR_2019_pred)
y_lasso_AGR_2020_pred = lasso_AGR_2020.predict(X_AGR_2020_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2020:")
print(y_lasso_AGR_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_lasso_ALL_2016_pred = lasso_ALL_2016.predict(X_ALL_2016_test)
print("\nKết quả dự đoán với tất cả các biến năm 2016:")
print(y_lasso_ALL_2016_pred)
y_lasso_ALL_2017_pred = lasso_ALL_2017.predict(X_ALL_2017_test)
print("\nKết quả dự đoán với tất cả các biến năm 2017:")
print(y_lasso_ALL_2017_pred)
y_lasso_ALL_2018_pred = lasso_ALL_2018.predict(X_ALL_2018_test)
print("\nKết quả dự đoán với tất cả các biến năm 2018:")
print(y_lasso_ALL_2018_pred)
y_lasso_ALL_2019_pred = lasso_ALL_2019.predict(X_ALL_2019_test)
print("\nKết quả dự đoán với tất cả các biến năm 2019:")
print(y_lasso_ALL_2019_pred)
y_lasso_ALL_2020_pred = lasso_ALL_2020.predict(X_ALL_2020_test)
print("\nKết quả dự đoán với tất cả các biến năm 2020:")
print(y_lasso_ALL_2020_pred)
# Out:
# Kết quả dự đoán với các biến CT năm 2016:
# [2.39431382 2.2942085  2.51336886 2.36423123 2.40149191 2.65260998
#  2.33660062 2.74544018 2.21902648 2.68932419 2.09142319 2.00464346
#  2.1886034  2.19923445 2.49794476 2.43583384 2.15527008 2.55986955
#  2.47023387 2.65206794 2.05386456 2.63329467 2.09435287 2.34902305
#  2.86798375 2.43273493 2.31500211 2.44713365 2.14780539 2.25084816
#  3.02995098 2.38132793 2.54432706 2.30508459 2.59591652 1.68896246
#  2.45097417 2.0178239  2.46245506 2.38844173 2.5765528  2.59025614
#  2.54511457 2.22514418 2.53754902 2.70038436 2.35178319 2.45702744
#  2.47972253 2.56077311 2.59691869 2.58214543 2.40290786 2.87741412
#  2.78299203 2.26736287 2.35912413 2.37259681 2.8112909  2.0914434
#  2.37429297 2.39122391 2.25067602 2.80393083 2.02833361 2.60078662
#  2.56974576 2.45689129 2.69925779 2.78337735 2.29065637 2.4987989
#  2.73167936 2.54091302 2.55637675 2.86842969 2.60699545 2.23583842
# ...

# %% [markdown]
# **Đánh giá mô hình**

# %% [markdown]
# Mô hình Lasso dự đoán với các biến CT

# %%
print("R2 score khi dự đoán với các biến CT:")

lasso_CT_2016_score = r2_score(y_2016_test, y_lasso_CT_2016_pred)
print("R2 score 2016: " +str(lasso_CT_2016_score))

lasso_CT_2017_score = r2_score(y_2017_test, y_lasso_CT_2017_pred)
print("R2 score 2017: " +str(lasso_CT_2017_score))

lasso_CT_2018_score = r2_score(y_2018_test, y_lasso_CT_2018_pred)
print("R2 score 2018: " +str(lasso_CT_2018_score))

lasso_CT_2019_score = r2_score(y_2019_test, y_lasso_CT_2019_pred)
print("R2 score 2019: " +str(lasso_CT_2019_score))

lasso_CT_2020_score = r2_score(y_2020_test, y_lasso_CT_2020_pred)
print("R2 score 2020: " +str(lasso_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến CT:
# R2 score 2016: 0.09246614323827762
# R2 score 2017: 0.2830625435153554
# R2 score 2018: 0.44619201739293746
# R2 score 2019: 0.27296364724813194
# R2 score 2020: 0.39048796554021103

# %% [markdown]
# Mô hình Lasso dự đoán với các biến NDVI

# %%
print("R2 score khi dự đoán với các biến NDVI:")

lasso_NDVI_2016_score = r2_score(y_2016_test, y_lasso_NDVI_2016_pred)
print("R2 score 2016: " +str(lasso_NDVI_2016_score))

lasso_NDVI_2017_score = r2_score(y_2017_test, y_lasso_NDVI_2017_pred)
print("R2 score 2017: " +str(lasso_NDVI_2017_score))

lasso_NDVI_2018_score = r2_score(y_2018_test, y_lasso_NDVI_2018_pred)
print("R2 score 2018: " +str(lasso_NDVI_2018_score))

lasso_NDVI_2019_score = r2_score(y_2019_test, y_lasso_NDVI_2019_pred)
print("R2 score 2019: " +str(lasso_NDVI_2019_score))

lasso_NDVI_2020_score = r2_score(y_2020_test, y_lasso_NDVI_2020_pred)
print("R2 score 2020: " +str(lasso_NDVI_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI:
# R2 score 2016: 0.28387473350960546
# R2 score 2017: 0.20099524967349092
# R2 score 2018: 0.506124642809735
# R2 score 2019: 0.468032437352197
# R2 score 2020: 0.46732979971746813

# %% [markdown]
# Mô hình Lasso dự đoán với các biến NDVI và các biến CT kết hợp

# %%
print("R2 score khi dự đoán với các biến NDVI và CT:")

lasso_NDVI_CT_2016_score = r2_score(y_2016_test, y_lasso_NDVI_CT_2016_pred)
print("R2 score 2016: " +str(lasso_NDVI_CT_2016_score))

lasso_NDVI_CT_2017_score = r2_score(y_2017_test, y_lasso_NDVI_CT_2017_pred)
print("R2 score 2017: " +str(lasso_NDVI_CT_2017_score))

lasso_NDVI_CT_2018_score = r2_score(y_2018_test, y_lasso_NDVI_CT_2018_pred)
print("R2 score 2018: " +str(lasso_NDVI_CT_2018_score))

lasso_NDVI_CT_2019_score = r2_score(y_2019_test, y_lasso_NDVI_CT_2019_pred)
print("R2 score 2019: " +str(lasso_NDVI_CT_2019_score))

lasso_NDVI_CT_2020_score = r2_score(y_2020_test, y_lasso_NDVI_CT_2020_pred)
print("R2 score 2020: " +str(lasso_NDVI_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI và CT:
# R2 score 2016: 0.31532923885508324
# R2 score 2017: 0.30480199745432346
# R2 score 2018: 0.5435048687824089
# R2 score 2019: 0.4768215490859934
# R2 score 2020: 0.5265612124845414

# %% [markdown]
# Mô hình Lasso dự đoán với các biến về đặc điểm nông học

# %%
print("R2 score khi dự đoán với các biến nhóm đặc điểm nông học:")

lasso_AGR_2016_score = r2_score(y_2016_test, y_lasso_AGR_2016_pred)
print("R2 score 2016: " +str(lasso_AGR_2016_score))

lasso_AGR_2017_score = r2_score(y_2017_test, y_lasso_AGR_2017_pred)
print("R2 score 2017: " +str(lasso_AGR_2017_score))

lasso_AGR_2018_score = r2_score(y_2018_test, y_lasso_AGR_2018_pred)
print("R2 score 2018: " +str(lasso_AGR_2018_score))

lasso_AGR_2019_score = r2_score(y_2019_test, y_lasso_AGR_2019_pred)
print("R2 score 2019: " +str(lasso_AGR_2019_score))

lasso_AGR_2020_score = r2_score(y_2020_test, y_lasso_AGR_2020_pred)
print("R2 score 2020: " +str(lasso_AGR_2020_score))
# Out:
# R2 score khi dự đoán với các biến nhóm đặc điểm nông học:
# R2 score 2016: 0.3802243784107795
# R2 score 2017: 0.3128749459929069
# R2 score 2018: 0.49129455334415373
# R2 score 2019: 0.2569382808834757
# R2 score 2020: 0.4296269472452342

# %% [markdown]
# Mô hình Lasso dự đoán với tất cả các biến

# %%
print("R2 score khi dự đoán với tất cả các biến:")

lasso_ALL_2016_score = r2_score(y_2016_test, y_lasso_ALL_2016_pred)
print("R2 score 2016: " +str(lasso_ALL_2016_score))

lasso_ALL_2017_score = r2_score(y_2017_test, y_lasso_ALL_2017_pred)
print("R2 score 2017: " +str(lasso_ALL_2017_score))

lasso_ALL_2018_score = r2_score(y_2018_test, y_lasso_ALL_2018_pred)
print("R2 score 2018: " +str(lasso_ALL_2018_score))

lasso_ALL_2019_score = r2_score(y_2019_test, y_lasso_ALL_2019_pred)
print("R2 score 2019: " +str(lasso_ALL_2019_score))

lasso_ALL_2020_score = r2_score(y_2020_test, y_lasso_ALL_2020_pred)
print("R2 score 2020: " +str(lasso_ALL_2020_score))
# Out:
# R2 score khi dự đoán với tất cả các biến:
# R2 score 2016: 0.5017693741060896
# R2 score 2017: 0.4959160375360856
# R2 score 2018: 0.6274052383779689
# R2 score 2019: 0.5348260559938993
# R2 score 2020: 0.6225205914669031

# %% [markdown]
# # Decision Tree

# %% [markdown]
# **Huấn luyện mô hình**

# %%
from sklearn.tree import DecisionTreeRegressor 
#Mô hình dự đoán với các biến CT theo từng năm
dtree_CT_2016 = DecisionTreeRegressor(max_depth= 5,
             max_features='log2',
             max_leaf_nodes= 30,
             min_samples_leaf= 8,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best'
            ) 
dtree_CT_2017 = DecisionTreeRegressor(max_depth= 3,
             max_features='auto',
             max_leaf_nodes= 10,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'random')  
dtree_CT_2018 = DecisionTreeRegressor(max_depth= 11,
             max_features='log2',
             max_leaf_nodes= 70,
             min_samples_leaf= 10,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best') 
dtree_CT_2019 = DecisionTreeRegressor(max_depth= 12,
             max_features='log2',
             max_leaf_nodes= 30,
             min_samples_leaf= 7,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best') 
dtree_CT_2020 = DecisionTreeRegressor(max_depth= 5,
             max_features='sqrt',
             max_leaf_nodes= 90,
             min_samples_leaf= 8,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
#Mô hình dự đoán với các biến NDVI theo từng năm
dtree_NDVI_2016 = DecisionTreeRegressor(max_depth= 5,
             max_features='log2',
             max_leaf_nodes= 60,
             min_samples_leaf= 4,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best') 
dtree_NDVI_2017 = DecisionTreeRegressor(max_depth= 11,
             max_features='auto',
             max_leaf_nodes=80,
             min_samples_leaf= 2,
             min_weight_fraction_leaf= 0.1,
             splitter= 'random') 
dtree_NDVI_2018 = DecisionTreeRegressor(max_depth= 12,
             max_features='sqrt',
             max_leaf_nodes= 10,
             min_samples_leaf= 10,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best') 
dtree_NDVI_2019 = DecisionTreeRegressor(max_depth= 3,
             max_features='log2',
             max_leaf_nodes= 60,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best') 
dtree_NDVI_2020 = DecisionTreeRegressor(max_depth= 7,
             max_features=None,
             max_leaf_nodes= 80,
             min_samples_leaf= 7,
             min_weight_fraction_leaf= 0.1,
             splitter= 'random')

#Mô hình dự đoán với các biến NDVI và CT theo từng năm
dtree_NDVI_CT_2016 = DecisionTreeRegressor(max_depth=5,
             max_features='log2',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_NDVI_CT_2017 = DecisionTreeRegressor(max_depth= 5,
     max_features='log2',
             max_leaf_nodes= 10,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_NDVI_CT_2018 = DecisionTreeRegressor(max_depth= 5,
             max_features='auto',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_NDVI_CT_2019 = DecisionTreeRegressor(max_depth= 5,
             max_features='auto',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_NDVI_CT_2020 = DecisionTreeRegressor(max_depth= 3,
             max_features='auto',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')

#Mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
dtree_AGR_2016 = DecisionTreeRegressor(max_depth= 3,
             max_features='log2',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_AGR_2017 = DecisionTreeRegressor(max_depth=5,
             max_features='auto',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_AGR_2018 = DecisionTreeRegressor(max_depth= 5,
             max_features='auto',
             max_leaf_nodes= 10,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'random')
dtree_AGR_2019 = DecisionTreeRegressor(max_depth= 5,
             max_features='auto',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'random')
dtree_AGR_2020 = DecisionTreeRegressor(max_depth= 5,
             max_features='auto',
             max_leaf_nodes= None,
             min_samples_leaf= 1,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')

#Mô hình dự đoán với tất cả các biến theo từng năm
dtree_ALL_2016 = DecisionTreeRegressor(max_depth= 9,
             max_features='sqrt',
             max_leaf_nodes=50,
             min_samples_leaf= 5,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_ALL_2017 = DecisionTreeRegressor(max_depth= 9,
             max_features='log2' ,
             max_leaf_nodes= 40,
             min_samples_leaf= 2,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_ALL_2018 = DecisionTreeRegressor(max_depth= 11,
             max_features='log2',
             max_leaf_nodes= 40,
             min_samples_leaf= 8,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')
dtree_ALL_2019 = DecisionTreeRegressor(max_depth= 11,
             max_features='auto',
             max_leaf_nodes= 80,
             min_samples_leaf= 10,
             min_weight_fraction_leaf= 0.1,
             splitter= 'random')
dtree_ALL_2020 =DecisionTreeRegressor(max_depth= 9,
             max_features='sqrt',
             max_leaf_nodes= 40,
             min_samples_leaf= 6,
             min_weight_fraction_leaf= 0.1,
             splitter= 'best')

#Huấn luyện mô hình dự đoán với các biến CT theo từng năm
dtree_CT_2016.fit(X_CT_2016_train, y_2016_train)
dtree_CT_2017.fit(X_CT_2017_train, y_2017_train)
dtree_CT_2018.fit(X_CT_2018_train, y_2018_train)
dtree_CT_2019.fit(X_CT_2019_train, y_2019_train)
dtree_CT_2020.fit(X_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI theo từng năm
dtree_NDVI_2016.fit(X_NDVI_2016_train, y_2016_train)
dtree_NDVI_2017.fit(X_NDVI_2017_train, y_2017_train)
dtree_NDVI_2018.fit(X_NDVI_2018_train, y_2018_train)
dtree_NDVI_2019.fit(X_NDVI_2019_train, y_2019_train)
dtree_NDVI_2020.fit(X_NDVI_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến NDVI và CT theo từng năm
dtree_NDVI_CT_2016.fit(X_NDVI_CT_2016_train, y_2016_train)
dtree_NDVI_CT_2017.fit(X_NDVI_CT_2017_train, y_2017_train)
dtree_NDVI_CT_2018.fit(X_NDVI_CT_2018_train, y_2018_train)
dtree_NDVI_CT_2019.fit(X_NDVI_CT_2019_train, y_2019_train)
dtree_NDVI_CT_2020.fit(X_NDVI_CT_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với các biến nhóm đặc điểm nông học theo từng năm
dtree_AGR_2016.fit(X_AGR_2016_train, y_2016_train)
dtree_AGR_2017.fit(X_AGR_2017_train, y_2017_train)
dtree_AGR_2018.fit(X_AGR_2018_train, y_2018_train)
dtree_AGR_2019.fit(X_AGR_2019_train, y_2019_train)
dtree_AGR_2020.fit(X_AGR_2020_train, y_2020_train)
#Huấn luyện mô hình dự đoán với tất cả các biến theo từng năm
dtree_ALL_2016.fit(X_ALL_2016_train, y_2016_train)
dtree_ALL_2017.fit(X_ALL_2017_train, y_2017_train)
dtree_ALL_2018.fit(X_ALL_2018_train, y_2018_train)
dtree_ALL_2019.fit(X_ALL_2019_train, y_2019_train)
dtree_ALL_2020.fit(X_ALL_2020_train, y_2020_train)
# Out:
# DecisionTreeRegressor(max_depth=9, max_features='sqrt', max_leaf_nodes=40,
#                       min_samples_leaf=6, min_weight_fraction_leaf=0.1)

# %% [markdown]
# **Dự đoán kết quả**

# %%
#Kết quả dự đoán với các biến CT
y_dtree_CT_2016_pred = dtree_CT_2016.predict(X_CT_2016_test)
print("Kết quả dự đoán với các biến CT năm 2016:")
print(y_dtree_CT_2016_pred)
y_dtree_CT_2017_pred = dtree_CT_2017.predict(X_CT_2017_test)
print("\nKết quả dự đoán với các biến CT năm 2017:")
print(y_dtree_CT_2017_pred)
y_dtree_CT_2018_pred = dtree_CT_2018.predict(X_CT_2018_test)
print("\nKết quả dự đoán với các biến CT năm 2018:")
print(y_dtree_CT_2018_pred)
y_dtree_CT_2019_pred = dtree_CT_2019.predict(X_CT_2019_test)
print("\nKết quả dự đoán với các biến CT năm 2019:")
print(y_dtree_CT_2019_pred)
y_dtree_CT_2020_pred = dtree_CT_2020.predict(X_CT_2020_test)
print("\nKết quả dự đoán với các biến CT năm 2020:")
print(y_dtree_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_dtree_NDVI_2016_pred = dtree_NDVI_2016.predict(X_NDVI_2016_test)
print("\nKết quả dự đoán với các biến NDVI năm 2016:")
print(y_dtree_NDVI_2016_pred)
y_dtree_NDVI_2017_pred = dtree_NDVI_2017.predict(X_NDVI_2017_test)
print("\nKết quả dự đoán với các biến NDVI năm 2017:")
print(y_dtree_NDVI_2017_pred)
y_dtree_NDVI_2018_pred = dtree_NDVI_2018.predict(X_NDVI_2018_test)
print("\nKết quả dự đoán với các biến NDVI năm 2018:")
print(y_dtree_NDVI_2018_pred)
y_dtree_NDVI_2019_pred = dtree_NDVI_2019.predict(X_NDVI_2019_test)
print("\nKết quả dự đoán với các biến NDVI năm 2019:")
print(y_dtree_NDVI_2019_pred)
y_dtree_NDVI_2020_pred = dtree_NDVI_2020.predict(X_NDVI_2020_test)
print("\nKết quả dự đoán với các biến NDVI năm 2020:")
print(y_dtree_NDVI_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_dtree_NDVI_CT_2016_pred = dtree_NDVI_CT_2016.predict(X_NDVI_CT_2016_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2016:")
print(y_dtree_NDVI_CT_2016_pred)
y_dtree_NDVI_CT_2017_pred = dtree_NDVI_CT_2017.predict(X_NDVI_CT_2017_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2017:")
print(y_dtree_NDVI_CT_2017_pred)
y_dtree_NDVI_CT_2018_pred = dtree_NDVI_CT_2018.predict(X_NDVI_CT_2018_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_dtree_NDVI_CT_2018_pred)
y_dtree_NDVI_CT_2019_pred = dtree_NDVI_CT_2019.predict(X_NDVI_CT_2019_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2018:")
print(y_dtree_NDVI_CT_2019_pred)
y_dtree_NDVI_CT_2020_pred = dtree_NDVI_CT_2020.predict(X_NDVI_CT_2020_test)
print("\nKết quả dự đoán với các biến NDVI VÀ CT năm 2020:")
print(y_dtree_NDVI_CT_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_dtree_AGR_2016_pred = dtree_AGR_2016.predict(X_AGR_2016_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2016:")
print(y_dtree_AGR_2016_pred)
y_dtree_AGR_2017_pred = dtree_AGR_2017.predict(X_AGR_2017_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2017:")
print(y_dtree_AGR_2017_pred)
y_dtree_AGR_2018_pred = dtree_AGR_2018.predict(X_AGR_2018_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2018:")
print(y_dtree_AGR_2018_pred)
y_dtree_AGR_2019_pred = dtree_AGR_2019.predict(X_AGR_2019_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2019:")
print(y_dtree_AGR_2019_pred)
y_dtree_AGR_2020_pred = dtree_AGR_2020.predict(X_AGR_2020_test)
print("\nKết quả dự đoán với các biến nhóm đặc điểm nông học năm 2020:")
print(y_dtree_AGR_2020_pred)

#Kết quả dự đoán với các biến CT
print("--------------------------------------------------------------------")
y_dtree_ALL_2016_pred = dtree_ALL_2016.predict(X_ALL_2016_test)
print("\nKết quả dự đoán với tất cả các biến năm 2016:")
print(y_dtree_ALL_2016_pred)
y_dtree_ALL_2017_pred = dtree_ALL_2017.predict(X_ALL_2017_test)
print("\nKết quả dự đoán với tất cả các biến năm 2017:")
print(y_dtree_ALL_2017_pred)
y_dtree_ALL_2018_pred = dtree_ALL_2018.predict(X_ALL_2018_test)
print("\nKết quả dự đoán với tất cả các biến năm 2018:")
print(y_dtree_ALL_2018_pred)
y_dtree_ALL_2019_pred = dtree_ALL_2019.predict(X_ALL_2019_test)
print("\nKết quả dự đoán với tất cả các biến năm 2019:")
print(y_dtree_ALL_2019_pred)
y_dtree_ALL_2020_pred = dtree_ALL_2020.predict(X_ALL_2020_test)
print("\nKết quả dự đoán với tất cả các biến năm 2020:")
print(y_dtree_ALL_2020_pred)
# Out:
# Kết quả dự đoán với các biến CT năm 2016:
# [2.45527778 2.37259615 2.45527778 2.45527778 2.74622449 2.37259615
#  2.0025     2.44375887 2.37259615 2.22367647 2.37259615 2.22367647
#  2.37259615 2.37259615 2.74622449 2.22367647 2.67771812 2.45527778
#  2.45527778 2.22367647 2.37259615 2.22367647 2.22367647 2.22367647
#  2.67771812 2.45527778 2.67771812 2.0025     2.67771812 2.44375887
#  2.45527778 2.0025     2.67771812 2.44375887 2.37259615 2.22367647
#  2.45527778 2.22367647 2.44375887 2.37259615 2.22367647 2.0025
#  2.74622449 2.45527778 2.44375887 2.67771812 2.37259615 2.22367647
#  2.67771812 2.22367647 2.0025     2.22367647 2.44375887 2.37259615
#  2.22367647 2.22367647 2.0025     2.37259615 2.67771812 2.22367647
#  2.0025     2.0025     2.37259615 2.67771812 2.0025     2.67771812
#  2.74622449 2.44375887 2.67771812 2.67771812 2.37259615 2.67771812
#  2.67771812 2.74622449 2.44375887 2.22367647 2.44375887 2.37259615
# ...

# %% [markdown]
# **Đánh giá mô hình**

# %% [markdown]
# Mô hình Decision Tree dự đoán với các biến CT

# %%
print("R2 score khi dự đoán với các biến CT:")

dtree_CT_2016_score = r2_score(y_2016_test, y_dtree_CT_2016_pred)
print("R2 score 2016: " +str(dtree_CT_2016_score))

dtree_CT_2017_score = r2_score(y_2017_test, y_dtree_CT_2017_pred)
print("R2 score 2017: " +str(dtree_CT_2017_score))

dtree_CT_2018_score = r2_score(y_2018_test, y_dtree_CT_2018_pred)
print("R2 score 2018: " +str(dtree_CT_2018_score))

dtree_CT_2019_score = r2_score(y_2019_test, y_dtree_CT_2019_pred)
print("R2 score 2019: " +str(dtree_CT_2019_score))

dtree_CT_2020_score = r2_score(y_2020_test, y_dtree_CT_2020_pred)
print("R2 score 2020: " +str(dtree_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến CT:
# R2 score 2016: 0.09156653211572519
# R2 score 2017: 0.18027489977877653
# R2 score 2018: 0.3832514832330547
# R2 score 2019: 0.19141559722244283
# R2 score 2020: 0.24468913962967853

# %% [markdown]
# Mô hình Decision Tree dự đoán với các biến NDVI

# %%
print("R2 score khi dự đoán với các biến NDVI:")

dtree_NDVI_2016_score = r2_score(y_2016_test, y_dtree_NDVI_2016_pred)
print("R2 score 2016: " +str(dtree_NDVI_2016_score))

dtree_NDVI_2017_score = r2_score(y_2017_test, y_dtree_NDVI_2017_pred)
print("R2 score 2017: " +str(dtree_NDVI_2017_score))

dtree_NDVI_2018_score = r2_score(y_2018_test, y_dtree_NDVI_2018_pred)
print("R2 score 2018: " +str(dtree_NDVI_2018_score))

dtree_NDVI_2019_score = r2_score(y_2019_test, y_dtree_NDVI_2019_pred)
print("R2 score 2019: " +str(dtree_NDVI_2019_score))

dtree_NDVI_2020_score = r2_score(y_2020_test, y_dtree_NDVI_2020_pred)
print("R2 score 2020: " +str(dtree_NDVI_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI:
# R2 score 2016: 0.15420560969620578
# R2 score 2017: 0.11926832197508841
# R2 score 2018: 0.32545874803631014
# R2 score 2019: 0.3250278250418107
# R2 score 2020: 0.3255664996812645

# %% [markdown]
# Mô hình Decision Tree dự đoán với các biến NDVI và các biến CT kết hợp

# %%
print("R2 score khi dự đoán với các biến NDVI và CT:")

dtree_NDVI_CT_2016_score = r2_score(y_2016_test, y_dtree_NDVI_CT_2016_pred)
print("R2 score 2016: " +str(dtree_NDVI_CT_2016_score))

dtree_NDVI_CT_2017_score = r2_score(y_2017_test, y_dtree_NDVI_CT_2017_pred)
print("R2 score 2017: " +str(dtree_NDVI_CT_2017_score))

dtree_NDVI_CT_2018_score = r2_score(y_2018_test, y_dtree_NDVI_CT_2018_pred)
print("R2 score 2018: " +str(dtree_NDVI_CT_2018_score))

dtree_NDVI_CT_2019_score = r2_score(y_2019_test, y_dtree_NDVI_CT_2019_pred)
print("R2 score 2019: " +str(dtree_NDVI_CT_2019_score))

dtree_NDVI_CT_2020_score = r2_score(y_2020_test, y_dtree_NDVI_CT_2020_pred)
print("R2 score 2020: " +str(dtree_NDVI_CT_2020_score))
# Out:
# R2 score khi dự đoán với các biến NDVI và CT:
# R2 score 2016: 0.19832712885687775
# R2 score 2017: 0.14222051258122304
# R2 score 2018: 0.4392703470923853
# R2 score 2019: 0.37825524876751415
# R2 score 2020: 0.3875487248303707

# %% [markdown]
# Mô hình Decision Tree dự đoán với các biến về đặc điểm nông học

# %%
print("R2 score khi dự đoán với các biến nhóm đặc điểm nông học:")

dtree_AGR_2016_score = r2_score(y_2016_test, y_dtree_AGR_2016_pred)
print("R2 score 2016: " +str(dtree_AGR_2016_score))

dtree_AGR_2017_score = r2_score(y_2017_test, y_dtree_AGR_2017_pred)
print("R2 score 2017: " +str(dtree_AGR_2017_score))

dtree_AGR_2018_score = r2_score(y_2018_test, y_dtree_AGR_2018_pred)
print("R2 score 2018: " +str(dtree_AGR_2018_score))

dtree_AGR_2019_score = r2_score(y_2019_test, y_dtree_AGR_2019_pred)
print("R2 score 2019: " +str(dtree_AGR_2019_score))

dtree_AGR_2020_score = r2_score(y_2020_test, y_dtree_AGR_2020_pred)
print("R2 score 2020: " +str(dtree_AGR_2020_score))
# Out:
# R2 score khi dự đoán với các biến nhóm đặc điểm nông học:
# R2 score 2016: 0.16104076016115798
# R2 score 2017: 0.1599856281983847
# R2 score 2018: 0.2130228268218003
# R2 score 2019: -0.005764631396836695
# R2 score 2020: 0.2476377116895926

# %% [markdown]
# Mô hình Decision Tree dự đoán với tất cả các biến

# %%
print("R2 score khi dự đoán với tất cả các biến:")

dtree_ALL_2016_score = r2_score(y_2016_test, y_dtree_ALL_2016_pred)
print("R2 score 2016: " +str(dtree_ALL_2016_score))

dtree_ALL_2017_score = r2_score(y_2017_test, y_dtree_ALL_2017_pred)
print("R2 score 2017: " +str(dtree_ALL_2017_score))

dtree_ALL_2018_score = r2_score(y_2018_test, y_dtree_ALL_2018_pred)
print("R2 score 2018: " +str(dtree_ALL_2018_score))

dtree_ALL_2019_score = r2_score(y_2019_test, y_dtree_ALL_2019_pred)
print("R2 score 2019: " +str(dtree_ALL_2019_score))

dtree_ALL_2020_score = r2_score(y_2020_test, y_dtree_ALL_2020_pred)
print("R2 score 2020: " +str(dtree_ALL_2020_score))
# Out:
# R2 score khi dự đoán với tất cả các biến:
# R2 score 2016: 0.16070826462468069
# R2 score 2017: 0.21448691260790664
# R2 score 2018: 0.3324993263181747
# R2 score 2019: 0.317224699874047
# R2 score 2020: 0.2745828778566828

# %% [markdown]
# # Colleration between y_pred and y_test

# %% [markdown]
# **Giá trị r khi dự đoán với các biến CT**

# %% [markdown]
# Mô hình SVR

# %%
import numpy as np
CT_2016_1_svr = pd.DataFrame(np.array(df_2016['CT_20160204']),columns=['y_pred'])
CT_2016_2_svr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
CT_2016_svr = pd.concat([CT_2016_1_svr, CT_2016_2_svr], axis=1, join='inner')

CT_2017_1_svr = pd.DataFrame(np.array(y_svr_CT_2017_pred),columns=['y_pred'])
CT_2017_2_svr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
CT_2017_svr = pd.concat([CT_2017_1_svr, CT_2017_2_svr], axis=1, join='inner')

CT_2018_1_svr = pd.DataFrame(np.array(y_svr_CT_2018_pred),columns=['y_pred'])
CT_2018_2_svr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
CT_2018_svr = pd.concat([CT_2018_1_svr, CT_2018_2_svr], axis=1, join='inner')

CT_2019_1_svr = pd.DataFrame(np.array(y_svr_CT_2019_pred),columns=['y_pred'])
CT_2019_2_svr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
CT_2019_svr = pd.concat([CT_2019_1_svr, CT_2019_2_svr], axis=1, join='inner')

CT_2020_1_svr = pd.DataFrame(np.array(y_svr_CT_2020_pred),columns=['y_pred'])
CT_2020_2_svr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
CT_2020_svr = pd.concat([CT_2020_1_svr, CT_2020_2_svr], axis=1, join='inner')

# %%
print(CT_2016_svr.corr())
print(CT_2017_svr.corr())
print(CT_2018_svr.corr())
print(CT_2019_svr.corr())
print(CT_2020_svr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000 -0.010154
# y_test -0.010154  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.560511
# y_test  0.560511  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.701469
# y_test  0.701469  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.549365
# y_test  0.549365  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.668497
# y_test  0.668497  1.000000

# %% [markdown]
# Mô hình RFR

# %%
CT_2016_1_rfr = pd.DataFrame(np.array(y_rfr_CT_2016_pred),columns=['y_pred'])
CT_2016_2_rfr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
CT_2016_rfr = pd.concat([CT_2016_1_rfr, CT_2016_2_rfr], axis=1, join='inner')

CT_2017_1_rfr = pd.DataFrame(np.array(y_rfr_CT_2017_pred),columns=['y_pred'])
CT_2017_2_rfr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
CT_2017_rfr = pd.concat([CT_2017_1_rfr, CT_2017_2_rfr], axis=1, join='inner')

CT_2018_1_rfr = pd.DataFrame(np.array(y_rfr_CT_2018_pred),columns=['y_pred'])
CT_2018_2_rfr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
CT_2018_rfr = pd.concat([CT_2018_1_rfr, CT_2018_2_rfr], axis=1, join='inner')

CT_2019_1_rfr = pd.DataFrame(np.array(y_rfr_CT_2019_pred),columns=['y_pred'])
CT_2019_2_rfr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
CT_2019_rfr = pd.concat([CT_2019_1_rfr, CT_2019_2_rfr], axis=1, join='inner')

CT_2020_1_rfr = pd.DataFrame(np.array(y_rfr_CT_2020_pred),columns=['y_pred'])
CT_2020_2_rfr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
CT_2020_rfr = pd.concat([CT_2020_1_rfr, CT_2020_2_rfr], axis=1, join='inner')

# %%
print(CT_2016_rfr.corr())
print(CT_2017_rfr.corr())
print(CT_2018_rfr.corr())
print(CT_2019_rfr.corr())
print(CT_2020_rfr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.455636
# y_test  0.455636  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.537775
# y_test  0.537775  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.708846
# y_test  0.708846  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.573727
# y_test  0.573727  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.678305
# y_test  0.678305  1.000000

# %% [markdown]
# Mô hình Ridge

# %%
CT_2016_1_ridge = pd.DataFrame(np.array(y_ridge_CT_2016_pred),columns=['y_pred'])
CT_2016_2_ridge = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
CT_2016_ridge = pd.concat([CT_2016_1_ridge, CT_2016_2_ridge], axis=1, join='inner')

CT_2017_1_ridge = pd.DataFrame(np.array(y_ridge_CT_2017_pred),columns=['y_pred'])
CT_2017_2_ridge = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
CT_2017_ridge = pd.concat([CT_2017_1_ridge, CT_2017_2_ridge], axis=1, join='inner')

CT_2018_1_ridge = pd.DataFrame(np.array(y_ridge_CT_2018_pred),columns=['y_pred'])
CT_2018_2_ridge = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
CT_2018_ridge = pd.concat([CT_2018_1_ridge, CT_2018_2_ridge], axis=1, join='inner')

CT_2019_1_ridge = pd.DataFrame(np.array(y_ridge_CT_2019_pred),columns=['y_pred'])
CT_2019_2_ridge = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
CT_2019_ridge = pd.concat([CT_2019_1_ridge, CT_2019_2_ridge], axis=1, join='inner')

CT_2020_1_ridge = pd.DataFrame(np.array(y_ridge_CT_2020_pred),columns=['y_pred'])
CT_2020_2_ridge = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
CT_2020_ridge = pd.concat([CT_2020_1_ridge, CT_2020_2_ridge], axis=1, join='inner')

# %%
print(CT_2016_ridge.corr())
print(CT_2017_ridge.corr())
print(CT_2018_ridge.corr())
print(CT_2019_ridge.corr())
print(CT_2020_ridge.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.317113
# y_test  0.317113  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.546128
# y_test  0.546128  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.672677
# y_test  0.672677  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.529968
# y_test  0.529968  1.000000
#          y_pred   y_test
# y_pred  1.00000  0.63919
# y_test  0.63919  1.00000

# %% [markdown]
# Mô hình Lasso

# %%
CT_2016_1_lasso = pd.DataFrame(np.array(y_lasso_CT_2016_pred),columns=['y_pred'])
CT_2016_2_lasso = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
CT_2016_lasso = pd.concat([CT_2016_1_lasso, CT_2016_2_lasso], axis=1, join='inner')

CT_2017_1_lasso = pd.DataFrame(np.array(y_lasso_CT_2017_pred),columns=['y_pred'])
CT_2017_2_lasso = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
CT_2017_lasso = pd.concat([CT_2017_1_lasso, CT_2017_2_lasso], axis=1, join='inner')

CT_2018_1_lasso = pd.DataFrame(np.array(y_lasso_CT_2018_pred),columns=['y_pred'])
CT_2018_2_lasso = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
CT_2018_lasso = pd.concat([CT_2018_1_lasso, CT_2018_2_lasso], axis=1, join='inner')

CT_2019_1_lasso = pd.DataFrame(np.array(y_lasso_CT_2019_pred),columns=['y_pred'])
CT_2019_2_lasso = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
CT_2019_lasso = pd.concat([CT_2019_1_lasso, CT_2019_2_lasso], axis=1, join='inner')

CT_2020_1_lasso = pd.DataFrame(np.array(y_lasso_CT_2020_pred),columns=['y_pred'])
CT_2020_2_lasso = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
CT_2020_lasso = pd.concat([CT_2020_1_lasso, CT_2020_2_lasso], axis=1, join='inner')

# %%
print(CT_2016_lasso.corr())
print(CT_2017_lasso.corr())
print(CT_2018_lasso.corr())
print(CT_2019_lasso.corr())
print(CT_2020_lasso.corr())
# Out:
#         y_pred  y_test
# y_pred  1.0000  0.3161
# y_test  0.3161  1.0000
#           y_pred    y_test
# y_pred  1.000000  0.541894
# y_test  0.541894  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.670062
# y_test  0.670062  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.524929
# y_test  0.524929  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.635885
# y_test  0.635885  1.000000

# %% [markdown]
# Mô hình Decision Tree

# %%
CT_2016_1_dtree = pd.DataFrame(np.array(y_dtree_CT_2016_pred),columns=['y_pred'])
CT_2016_2_dtree = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
CT_2016_dtree = pd.concat([CT_2016_1_dtree, CT_2016_2_dtree], axis=1, join='inner')

CT_2017_1_dtree = pd.DataFrame(np.array(y_dtree_CT_2017_pred),columns=['y_pred'])
CT_2017_2_dtree = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
CT_2017_dtree = pd.concat([CT_2017_1_dtree, CT_2017_2_dtree], axis=1, join='inner')

CT_2018_1_dtree = pd.DataFrame(np.array(y_dtree_CT_2018_pred),columns=['y_pred'])
CT_2018_2_dtree = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
CT_2018_dtree = pd.concat([CT_2018_1_dtree, CT_2018_2_dtree], axis=1, join='inner')

CT_2019_1_dtree = pd.DataFrame(np.array(y_dtree_CT_2019_pred),columns=['y_pred'])
CT_2019_2_dtree = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
CT_2019_dtree = pd.concat([CT_2019_1_dtree, CT_2019_2_dtree], axis=1, join='inner')

CT_2020_1_dtree = pd.DataFrame(np.array(y_dtree_CT_2020_pred),columns=['y_pred'])
CT_2020_2_dtree = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
CT_2020_dtree = pd.concat([CT_2020_1_dtree, CT_2020_2_dtree], axis=1, join='inner')

# %%
print(CT_2016_dtree.corr())
print(CT_2017_dtree.corr())
print(CT_2018_dtree.corr())
print(CT_2019_dtree.corr())
print(CT_2020_dtree.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.308986
# y_test  0.308986  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.444413
# y_test  0.444413  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.620296
# y_test  0.620296  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.445646
# y_test  0.445646  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.496558
# y_test  0.496558  1.000000

# %% [markdown]
# **Giá trị r khi dự đoán với các biến NDVI**

# %% [markdown]
# Mô hình SVR

# %%
NDVI_2016_1_svr = pd.DataFrame(np.array(y_svr_NDVI_2016_pred),columns=['y_pred'])
NDVI_2016_2_svr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_2016_svr = pd.concat([NDVI_2016_1_svr, NDVI_2016_2_svr], axis=1, join='inner')

NDVI_2017_1_svr = pd.DataFrame(np.array(y_svr_NDVI_2017_pred),columns=['y_pred'])
NDVI_2017_2_svr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_2017_svr = pd.concat([NDVI_2017_1_svr, NDVI_2017_2_svr], axis=1, join='inner')

NDVI_2018_1_svr = pd.DataFrame(np.array(y_svr_NDVI_2018_pred),columns=['y_pred'])
NDVI_2018_2_svr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_2018_svr = pd.concat([NDVI_2018_1_svr, NDVI_2018_2_svr], axis=1, join='inner')

NDVI_2019_1_svr = pd.DataFrame(np.array(y_svr_NDVI_2019_pred),columns=['y_pred'])
NDVI_2019_2_svr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_2019_svr = pd.concat([NDVI_2019_1_svr, NDVI_2019_2_svr], axis=1, join='inner')

NDVI_2020_1_svr = pd.DataFrame(np.array(y_svr_NDVI_2020_pred),columns=['y_pred'])
NDVI_2020_2_svr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_2020_svr = pd.concat([NDVI_2020_1_svr, NDVI_2020_2_svr], axis=1, join='inner')

print(NDVI_2016_svr.corr())
print(NDVI_2017_svr.corr())
print(NDVI_2018_svr.corr())
print(NDVI_2019_svr.corr())
print(NDVI_2020_svr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.526699
# y_test  0.526699  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.472508
# y_test  0.472508  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.705064
# y_test  0.705064  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.678968
# y_test  0.678968  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.686524
# y_test  0.686524  1.000000

# %% [markdown]
# Mô hình RFR

# %%
NDVI_2016_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_2016_pred),columns=['y_pred'])
NDVI_2016_2_rfr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_2016_rfr = pd.concat([NDVI_2016_1_rfr, NDVI_2016_2_rfr], axis=1, join='inner')

NDVI_2017_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_2017_pred),columns=['y_pred'])
NDVI_2017_2_rfr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_2017_rfr = pd.concat([NDVI_2017_1_rfr, NDVI_2017_2_rfr], axis=1, join='inner')

NDVI_2018_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_2018_pred),columns=['y_pred'])
NDVI_2018_2_rfr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_2018_rfr = pd.concat([NDVI_2018_1_rfr, NDVI_2018_2_rfr], axis=1, join='inner')

NDVI_2019_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_2019_pred),columns=['y_pred'])
NDVI_2019_2_rfr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_2019_rfr = pd.concat([NDVI_2019_1_rfr, NDVI_2019_2_rfr], axis=1, join='inner')

NDVI_2020_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_2020_pred),columns=['y_pred'])
NDVI_2020_2_rfr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_2020_rfr = pd.concat([NDVI_2020_1_rfr, NDVI_2020_2_rfr], axis=1, join='inner')

print(NDVI_2016_rfr.corr())
print(NDVI_2017_rfr.corr())
print(NDVI_2018_rfr.corr())
print(NDVI_2019_rfr.corr())
print(NDVI_2020_rfr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.543321
# y_test  0.543321  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.515766
# y_test  0.515766  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.704664
# y_test  0.704664  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.685754
# y_test  0.685754  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.695075
# y_test  0.695075  1.000000

# %% [markdown]
# Mô hình Ridge

# %%
NDVI_2016_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_2016_pred),columns=['y_pred'])
NDVI_2016_2_ridge = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_2016_ridge = pd.concat([NDVI_2016_1_ridge, NDVI_2016_2_ridge], axis=1, join='inner')

NDVI_2017_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_2017_pred),columns=['y_pred'])
NDVI_2017_2_ridge = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_2017_ridge = pd.concat([NDVI_2017_1_ridge, NDVI_2017_2_ridge], axis=1, join='inner')

NDVI_2018_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_2018_pred),columns=['y_pred'])
NDVI_2018_2_ridge = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_2018_ridge = pd.concat([NDVI_2018_1_ridge, NDVI_2018_2_ridge], axis=1, join='inner')

NDVI_2019_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_2019_pred),columns=['y_pred'])
NDVI_2019_2_ridge = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_2019_ridge = pd.concat([NDVI_2019_1_ridge, NDVI_2019_2_ridge], axis=1, join='inner')

NDVI_2020_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_2020_pred),columns=['y_pred'])
NDVI_2020_2_ridge = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_2020_ridge = pd.concat([NDVI_2020_1_ridge, NDVI_2020_2_ridge], axis=1, join='inner')

print(NDVI_2016_ridge.corr())
print(NDVI_2017_ridge.corr())
print(NDVI_2018_ridge.corr())
print(NDVI_2019_ridge.corr())
print(NDVI_2020_ridge.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.541571
# y_test  0.541571  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.460019
# y_test  0.460019  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.714708
# y_test  0.714708  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.686723
# y_test  0.686723  1.000000
#          y_pred   y_test
# y_pred  1.00000  0.68546
# y_test  0.68546  1.00000

# %% [markdown]
# Mô hình Lasso

# %%
NDVI_2016_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_2016_pred),columns=['y_pred'])
NDVI_2016_2_lasso = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_2016_lasso = pd.concat([NDVI_2016_1_lasso, NDVI_2016_2_lasso], axis=1, join='inner')

NDVI_2017_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_2017_pred),columns=['y_pred'])
NDVI_2017_2_lasso = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_2017_lasso = pd.concat([NDVI_2017_1_lasso, NDVI_2017_2_lasso], axis=1, join='inner')

NDVI_2018_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_2018_pred),columns=['y_pred'])
NDVI_2018_2_lasso = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_2018_lasso = pd.concat([NDVI_2018_1_lasso, NDVI_2018_2_lasso], axis=1, join='inner')

NDVI_2019_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_2019_pred),columns=['y_pred'])
NDVI_2019_2_lasso = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_2019_lasso = pd.concat([NDVI_2019_1_lasso, NDVI_2019_2_lasso], axis=1, join='inner')

NDVI_2020_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_2020_pred),columns=['y_pred'])
NDVI_2020_2_lasso = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_2020_lasso = pd.concat([NDVI_2020_1_lasso, NDVI_2020_2_lasso], axis=1, join='inner')

print(NDVI_2016_lasso.corr())
print(NDVI_2017_lasso.corr())
print(NDVI_2018_lasso.corr())
print(NDVI_2019_lasso.corr())
print(NDVI_2020_lasso.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.535146
# y_test  0.535146  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.464976
# y_test  0.464976  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.712158
# y_test  0.712158  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.686739
# y_test  0.686739  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.685441
# y_test  0.685441  1.000000

# %% [markdown]
# Mô hình Decision Tree

# %%
NDVI_2016_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_2016_pred),columns=['y_pred'])
NDVI_2016_2_dtree = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_2016_dtree = pd.concat([NDVI_2016_1_dtree, NDVI_2016_2_dtree], axis=1, join='inner')

NDVI_2017_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_2017_pred),columns=['y_pred'])
NDVI_2017_2_dtree = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_2017_dtree = pd.concat([NDVI_2017_1_dtree, NDVI_2017_2_dtree], axis=1, join='inner')

NDVI_2018_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_2018_pred),columns=['y_pred'])
NDVI_2018_2_dtree = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_2018_dtree = pd.concat([NDVI_2018_1_dtree, NDVI_2018_2_dtree], axis=1, join='inner')

NDVI_2019_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_2019_pred),columns=['y_pred'])
NDVI_2019_2_dtree = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_2019_dtree = pd.concat([NDVI_2019_1_dtree, NDVI_2019_2_dtree], axis=1, join='inner')

NDVI_2020_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_2020_pred),columns=['y_pred'])
NDVI_2020_2_dtree = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_2020_dtree = pd.concat([NDVI_2020_1_dtree, NDVI_2020_2_dtree], axis=1, join='inner')

print(NDVI_2016_dtree.corr())
print(NDVI_2017_dtree.corr())
print(NDVI_2018_dtree.corr())
print(NDVI_2019_dtree.corr())
print(NDVI_2020_dtree.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.398248
# y_test  0.398248  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.350342
# y_test  0.350342  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.571186
# y_test  0.571186  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.572848
# y_test  0.572848  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.580489
# y_test  0.580489  1.000000

# %% [markdown]
# **Giá trị r khi dự đoán với các biến NDVI_CT**

# %% [markdown]
# Mô hình SVR

# %%
NDVI_CT_2016_1_svr = pd.DataFrame(np.array(y_svr_NDVI_CT_2016_pred),columns=['y_pred'])
NDVI_CT_2016_2_svr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_CT_2016_svr = pd.concat([NDVI_CT_2016_1_svr, NDVI_CT_2016_2_svr], axis=1, join='inner')

NDVI_CT_2017_1_svr = pd.DataFrame(np.array(y_svr_NDVI_CT_2017_pred),columns=['y_pred'])
NDVI_CT_2017_2_svr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_CT_2017_svr = pd.concat([NDVI_CT_2017_1_svr, NDVI_CT_2017_2_svr], axis=1, join='inner')

NDVI_CT_2018_1_svr = pd.DataFrame(np.array(y_svr_NDVI_CT_2018_pred),columns=['y_pred'])
NDVI_CT_2018_2_svr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_CT_2018_svr = pd.concat([NDVI_CT_2018_1_svr, NDVI_CT_2018_2_svr], axis=1, join='inner')

NDVI_CT_2019_1_svr = pd.DataFrame(np.array(y_svr_NDVI_CT_2019_pred),columns=['y_pred'])
NDVI_CT_2019_2_svr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_CT_2019_svr = pd.concat([NDVI_CT_2019_1_svr, NDVI_CT_2019_2_svr], axis=1, join='inner')

NDVI_CT_2020_1_svr = pd.DataFrame(np.array(y_svr_NDVI_CT_2020_pred),columns=['y_pred'])
NDVI_CT_2020_2_svr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_CT_2020_svr = pd.concat([NDVI_CT_2020_1_svr, NDVI_CT_2020_2_svr], axis=1, join='inner')

print(NDVI_CT_2016_svr.corr())
print(NDVI_CT_2017_svr.corr())
print(NDVI_CT_2018_svr.corr())
print(NDVI_CT_2019_svr.corr())
print(NDVI_CT_2020_svr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.576274
# y_test  0.576274  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.572402
# y_test  0.572402  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.735767
# y_test  0.735767  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.672705
# y_test  0.672705  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.745025
# y_test  0.745025  1.000000

# %% [markdown]
# Mô hình RFR

# %%
NDVI_CT_2016_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_CT_2016_pred),columns=['y_pred'])
NDVI_CT_2016_2_rfr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_CT_2016_rfr = pd.concat([NDVI_CT_2016_1_rfr, NDVI_CT_2016_2_rfr], axis=1, join='inner')

NDVI_CT_2017_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_CT_2017_pred),columns=['y_pred'])
NDVI_CT_2017_2_rfr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_CT_2017_rfr = pd.concat([NDVI_CT_2017_1_rfr, NDVI_CT_2017_2_rfr], axis=1, join='inner')

NDVI_CT_2018_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_CT_2018_pred),columns=['y_pred'])
NDVI_CT_2018_2_rfr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_CT_2018_rfr = pd.concat([NDVI_CT_2018_1_rfr, NDVI_CT_2018_2_rfr], axis=1, join='inner')

NDVI_CT_2019_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_CT_2019_pred),columns=['y_pred'])
NDVI_CT_2019_2_rfr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_CT_2019_rfr = pd.concat([NDVI_CT_2019_1_rfr, NDVI_CT_2019_2_rfr], axis=1, join='inner')

NDVI_CT_2020_1_rfr = pd.DataFrame(np.array(y_rfr_NDVI_CT_2020_pred),columns=['y_pred'])
NDVI_CT_2020_2_rfr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_CT_2020_rfr = pd.concat([NDVI_CT_2020_1_rfr, NDVI_CT_2020_2_rfr], axis=1, join='inner')

print(NDVI_CT_2016_rfr.corr())
print(NDVI_CT_2017_rfr.corr())
print(NDVI_CT_2018_rfr.corr())
print(NDVI_CT_2019_rfr.corr())
print(NDVI_CT_2020_rfr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.631327
# y_test  0.631327  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.580939
# y_test  0.580939  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.744997
# y_test  0.744997  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.703336
# y_test  0.703336  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.741254
# y_test  0.741254  1.000000

# %% [markdown]
# Mô hình Ridge

# %%
NDVI_CT_2016_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_CT_2016_pred),columns=['y_pred'])
NDVI_CT_2016_2_ridge = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_CT_2016_ridge = pd.concat([NDVI_CT_2016_1_ridge, NDVI_CT_2016_2_ridge], axis=1, join='inner')

NDVI_CT_2017_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_CT_2017_pred),columns=['y_pred'])
NDVI_CT_2017_2_ridge = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_CT_2017_ridge = pd.concat([NDVI_CT_2017_1_ridge, NDVI_CT_2017_2_ridge], axis=1, join='inner')

NDVI_CT_2018_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_CT_2018_pred),columns=['y_pred'])
NDVI_CT_2018_2_ridge = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_CT_2018_ridge = pd.concat([NDVI_CT_2018_1_ridge, NDVI_CT_2018_2_ridge], axis=1, join='inner')

NDVI_CT_2019_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_CT_2019_pred),columns=['y_pred'])
NDVI_CT_2019_2_ridge = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_CT_2019_ridge = pd.concat([NDVI_CT_2019_1_ridge, NDVI_CT_2019_2_ridge], axis=1, join='inner')

NDVI_CT_2020_1_ridge = pd.DataFrame(np.array(y_ridge_NDVI_CT_2020_pred),columns=['y_pred'])
NDVI_CT_2020_2_ridge = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_CT_2020_ridge = pd.concat([NDVI_CT_2020_1_ridge, NDVI_CT_2020_2_ridge], axis=1, join='inner')

print(NDVI_CT_2016_ridge.corr())
print(NDVI_CT_2017_ridge.corr())
print(NDVI_CT_2018_ridge.corr())
print(NDVI_CT_2019_ridge.corr())
print(NDVI_CT_2020_ridge.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.562303
# y_test  0.562303  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.558452
# y_test  0.558452  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.740998
# y_test  0.740998  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.688985
# y_test  0.688985  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.729228
# y_test  0.729228  1.000000

# %% [markdown]
# Mô hình Lasso

# %%
NDVI_CT_2016_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_CT_2016_pred),columns=['y_pred'])
NDVI_CT_2016_2_lasso = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_CT_2016_lasso = pd.concat([NDVI_CT_2016_1_lasso, NDVI_CT_2016_2_lasso], axis=1, join='inner')

NDVI_CT_2017_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_CT_2017_pred),columns=['y_pred'])
NDVI_CT_2017_2_lasso = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_CT_2017_lasso = pd.concat([NDVI_CT_2017_1_lasso, NDVI_CT_2017_2_lasso], axis=1, join='inner')

NDVI_CT_2018_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_CT_2018_pred),columns=['y_pred'])
NDVI_CT_2018_2_lasso = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_CT_2018_lasso = pd.concat([NDVI_CT_2018_1_lasso, NDVI_CT_2018_2_lasso], axis=1, join='inner')

NDVI_CT_2019_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_CT_2019_pred),columns=['y_pred'])
NDVI_CT_2019_2_lasso = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_CT_2019_lasso = pd.concat([NDVI_CT_2019_1_lasso, NDVI_CT_2019_2_lasso], axis=1, join='inner')

NDVI_CT_2020_1_lasso = pd.DataFrame(np.array(y_lasso_NDVI_CT_2020_pred),columns=['y_pred'])
NDVI_CT_2020_2_lasso = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_CT_2020_lasso = pd.concat([NDVI_CT_2020_1_lasso, NDVI_CT_2020_2_lasso], axis=1, join='inner')

print(NDVI_CT_2016_lasso.corr())
print(NDVI_CT_2017_lasso.corr())
print(NDVI_CT_2018_lasso.corr())
print(NDVI_CT_2019_lasso.corr())
print(NDVI_CT_2020_lasso.corr())
# Out:
#          y_pred   y_test
# y_pred  1.00000  0.56218
# y_test  0.56218  1.00000
#          y_pred   y_test
# y_pred  1.00000  0.55852
# y_test  0.55852  1.00000
#           y_pred    y_test
# y_pred  1.000000  0.737923
# y_test  0.737923  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.690787
# y_test  0.690787  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.729088
# y_test  0.729088  1.000000

# %% [markdown]
# Mô hình Decision Tree

# %%
NDVI_CT_2016_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_CT_2016_pred),columns=['y_pred'])
NDVI_CT_2016_2_dtree = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
NDVI_CT_2016_dtree = pd.concat([NDVI_CT_2016_1_dtree, NDVI_CT_2016_2_dtree], axis=1, join='inner')

NDVI_CT_2017_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_CT_2017_pred),columns=['y_pred'])
NDVI_CT_2017_2_dtree = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
NDVI_CT_2017_dtree = pd.concat([NDVI_CT_2017_1_dtree, NDVI_CT_2017_2_dtree], axis=1, join='inner')

NDVI_CT_2018_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_CT_2018_pred),columns=['y_pred'])
NDVI_CT_2018_2_dtree = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
NDVI_CT_2018_dtree = pd.concat([NDVI_CT_2018_1_dtree, NDVI_CT_2018_2_dtree], axis=1, join='inner')

NDVI_CT_2019_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_CT_2019_pred),columns=['y_pred'])
NDVI_CT_2019_2_dtree = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
NDVI_CT_2019_dtree = pd.concat([NDVI_CT_2019_1_dtree, NDVI_CT_2019_2_dtree], axis=1, join='inner')

NDVI_CT_2020_1_dtree = pd.DataFrame(np.array(y_dtree_NDVI_CT_2020_pred),columns=['y_pred'])
NDVI_CT_2020_2_dtree = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
NDVI_CT_2020_dtree = pd.concat([NDVI_CT_2020_1_dtree, NDVI_CT_2020_2_dtree], axis=1, join='inner')

print(NDVI_CT_2016_dtree.corr())
print(NDVI_CT_2017_dtree.corr())
print(NDVI_CT_2018_dtree.corr())
print(NDVI_CT_2019_dtree.corr())
print(NDVI_CT_2020_dtree.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.446169
# y_test  0.446169  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.387841
# y_test  0.387841  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.663569
# y_test  0.663569  1.000000
#          y_pred   y_test
# y_pred  1.00000  0.61931
# y_test  0.61931  1.00000
#           y_pred    y_test
# y_pred  1.000000  0.622843
# y_test  0.622843  1.000000

# %% [markdown]
# **Giá trị r khi dự đoán với các biến thuộc nhóm đặc điểm nông học**
#
# Mô hình SVR

# %%
AGR_2016_1_svr = pd.DataFrame(np.array(y_svr_AGR_2016_pred),columns=['y_pred'])
AGR_2016_2_svr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
AGR_2016_svr = pd.concat([AGR_2016_1_svr, AGR_2016_2_svr], axis=1, join='inner')

AGR_2017_1_svr = pd.DataFrame(np.array(y_svr_AGR_2017_pred),columns=['y_pred'])
AGR_2017_2_svr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
AGR_2017_svr = pd.concat([AGR_2017_1_svr, AGR_2017_2_svr], axis=1, join='inner')

AGR_2018_1_svr = pd.DataFrame(np.array(y_svr_AGR_2018_pred),columns=['y_pred'])
AGR_2018_2_svr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
AGR_2018_svr = pd.concat([AGR_2018_1_svr, AGR_2018_2_svr], axis=1, join='inner')

AGR_2019_1_svr = pd.DataFrame(np.array(y_svr_AGR_2019_pred),columns=['y_pred'])
AGR_2019_2_svr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
AGR_2019_svr = pd.concat([AGR_2019_1_svr, AGR_2019_2_svr], axis=1, join='inner')

AGR_2020_1_svr = pd.DataFrame(np.array(y_svr_AGR_2020_pred),columns=['y_pred'])
AGR_2020_2_svr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
AGR_2020_svr = pd.concat([AGR_2020_1_svr, AGR_2020_2_svr], axis=1, join='inner')

print(AGR_2016_svr.corr())
print(AGR_2017_svr.corr())
print(AGR_2018_svr.corr())
print(AGR_2019_svr.corr())
print(AGR_2020_svr.corr())
# Out:
#          y_pred   y_test
# y_pred  1.00000  0.63414
# y_test  0.63414  1.00000
#           y_pred    y_test
# y_pred  1.000000  0.598236
# y_test  0.598236  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.708217
# y_test  0.708217  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.525652
# y_test  0.525652  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.675257
# y_test  0.675257  1.000000

# %% [markdown]
# Mô hình RFR

# %%
AGR_2016_1_rfr = pd.DataFrame(np.array(y_rfr_AGR_2016_pred),columns=['y_pred'])
AGR_2016_2_rfr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
AGR_2016_rfr = pd.concat([AGR_2016_1_rfr, AGR_2016_2_rfr], axis=1, join='inner')

AGR_2017_1_rfr = pd.DataFrame(np.array(y_rfr_AGR_2017_pred),columns=['y_pred'])
AGR_2017_2_rfr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
AGR_2017_rfr = pd.concat([AGR_2017_1_rfr, AGR_2017_2_rfr], axis=1, join='inner')

AGR_2018_1_rfr = pd.DataFrame(np.array(y_rfr_AGR_2018_pred),columns=['y_pred'])
AGR_2018_2_rfr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
AGR_2018_rfr = pd.concat([AGR_2018_1_rfr, AGR_2018_2_rfr], axis=1, join='inner')

AGR_2019_1_rfr = pd.DataFrame(np.array(y_rfr_AGR_2019_pred),columns=['y_pred'])
AGR_2019_2_rfr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
AGR_2019_rfr = pd.concat([AGR_2019_1_rfr, AGR_2019_2_rfr], axis=1, join='inner')

AGR_2020_1_rfr = pd.DataFrame(np.array(y_rfr_AGR_2020_pred),columns=['y_pred'])
AGR_2020_2_rfr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
AGR_2020_rfr = pd.concat([AGR_2020_1_rfr, AGR_2020_2_rfr], axis=1, join='inner')

print(AGR_2016_rfr.corr())
print(AGR_2017_rfr.corr())
print(AGR_2018_rfr.corr())
print(AGR_2019_rfr.corr())
print(AGR_2020_rfr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.613474
# y_test  0.613474  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.601027
# y_test  0.601027  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.663034
# y_test  0.663034  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.526962
# y_test  0.526962  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.611712
# y_test  0.611712  1.000000

# %% [markdown]
# Mô hình Ridge

# %%
AGR_2016_1_ridge = pd.DataFrame(np.array(y_ridge_AGR_2016_pred),columns=['y_pred'])
AGR_2016_2_ridge = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
AGR_2016_ridge = pd.concat([AGR_2016_1_ridge, AGR_2016_2_ridge], axis=1, join='inner')

AGR_2017_1_ridge = pd.DataFrame(np.array(y_ridge_AGR_2017_pred),columns=['y_pred'])
AGR_2017_2_ridge = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
AGR_2017_ridge = pd.concat([AGR_2017_1_ridge, AGR_2017_2_ridge], axis=1, join='inner')

AGR_2018_1_ridge = pd.DataFrame(np.array(y_ridge_AGR_2018_pred),columns=['y_pred'])
AGR_2018_2_ridge = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
AGR_2018_ridge = pd.concat([AGR_2018_1_ridge, AGR_2018_2_ridge], axis=1, join='inner')

AGR_2019_1_ridge = pd.DataFrame(np.array(y_ridge_AGR_2019_pred),columns=['y_pred'])
AGR_2019_2_ridge = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
AGR_2019_ridge = pd.concat([AGR_2019_1_ridge, AGR_2019_2_ridge], axis=1, join='inner')

AGR_2020_1_ridge = pd.DataFrame(np.array(y_ridge_AGR_2020_pred),columns=['y_pred'])
AGR_2020_2_ridge = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
AGR_2020_ridge = pd.concat([AGR_2020_1_ridge, AGR_2020_2_ridge], axis=1, join='inner')

print(AGR_2016_ridge.corr())
print(AGR_2017_ridge.corr())
print(AGR_2018_ridge.corr())
print(AGR_2019_ridge.corr())
print(AGR_2020_ridge.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.617885
# y_test  0.617885  1.000000
#          y_pred   y_test
# y_pred  1.00000  0.56583
# y_test  0.56583  1.00000
#           y_pred    y_test
# y_pred  1.000000  0.702915
# y_test  0.702915  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.508795
# y_test  0.508795  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.664434
# y_test  0.664434  1.000000

# %% [markdown]
# Mô hình Lasso

# %%
AGR_2016_1_lasso = pd.DataFrame(np.array(y_lasso_AGR_2016_pred),columns=['y_pred'])
AGR_2016_2_lasso = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
AGR_2016_lasso = pd.concat([AGR_2016_1_lasso, AGR_2016_2_lasso], axis=1, join='inner')

AGR_2017_1_lasso = pd.DataFrame(np.array(y_lasso_AGR_2017_pred),columns=['y_pred'])
AGR_2017_2_lasso = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
AGR_2017_lasso = pd.concat([AGR_2017_1_lasso, AGR_2017_2_lasso], axis=1, join='inner')

AGR_2018_1_lasso = pd.DataFrame(np.array(y_lasso_AGR_2018_pred),columns=['y_pred'])
AGR_2018_2_lasso = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
AGR_2018_lasso = pd.concat([AGR_2018_1_lasso, AGR_2018_2_lasso], axis=1, join='inner')

AGR_2019_1_lasso = pd.DataFrame(np.array(y_lasso_AGR_2019_pred),columns=['y_pred'])
AGR_2019_2_lasso = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
AGR_2019_lasso = pd.concat([AGR_2019_1_lasso, AGR_2019_2_lasso], axis=1, join='inner')

AGR_2020_1_lasso = pd.DataFrame(np.array(y_lasso_AGR_2020_pred),columns=['y_pred'])
AGR_2020_2_lasso = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
AGR_2020_lasso = pd.concat([AGR_2020_1_lasso, AGR_2020_2_lasso], axis=1, join='inner')

print(AGR_2016_lasso.corr())
print(AGR_2017_lasso.corr())
print(AGR_2018_lasso.corr())
print(AGR_2019_lasso.corr())
print(AGR_2020_lasso.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.617764
# y_test  0.617764  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.565863
# y_test  0.565863  1.000000
#         y_pred  y_test
# y_pred  1.0000  0.7033
# y_test  0.7033  1.0000
#           y_pred    y_test
# y_pred  1.000000  0.508744
# y_test  0.508744  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.664137
# y_test  0.664137  1.000000

# %% [markdown]
# Mô hình Decision Tree

# %%
AGR_2016_1_dtree = pd.DataFrame(np.array(y_dtree_AGR_2016_pred),columns=['y_pred'])
AGR_2016_2_dtree = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
AGR_2016_dtree = pd.concat([AGR_2016_1_dtree, AGR_2016_2_dtree], axis=1, join='inner')

AGR_2017_1_dtree = pd.DataFrame(np.array(y_dtree_AGR_2017_pred),columns=['y_pred'])
AGR_2017_2_dtree = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
AGR_2017_dtree = pd.concat([AGR_2017_1_dtree, AGR_2017_2_dtree], axis=1, join='inner')

AGR_2018_1_dtree = pd.DataFrame(np.array(y_dtree_AGR_2018_pred),columns=['y_pred'])
AGR_2018_2_dtree = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
AGR_2018_dtree = pd.concat([AGR_2018_1_dtree, AGR_2018_2_dtree], axis=1, join='inner')

AGR_2019_1_dtree = pd.DataFrame(np.array(y_dtree_AGR_2019_pred),columns=['y_pred'])
AGR_2019_2_dtree = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
AGR_2019_dtree = pd.concat([AGR_2019_1_dtree, AGR_2019_2_dtree], axis=1, join='inner')

AGR_2020_1_dtree = pd.DataFrame(np.array(y_dtree_AGR_2020_pred),columns=['y_pred'])
AGR_2020_2_dtree = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
AGR_2020_dtree = pd.concat([AGR_2020_1_dtree, AGR_2020_2_dtree], axis=1, join='inner')

print(AGR_2016_dtree.corr())
print(AGR_2017_dtree.corr())
print(AGR_2018_dtree.corr())
print(AGR_2019_dtree.corr())
print(AGR_2020_dtree.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.404752
# y_test  0.404752  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.413891
# y_test  0.413891  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.462729
# y_test  0.462729  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.093813
# y_test  0.093813  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.501373
# y_test  0.501373  1.000000

# %% [markdown]
# **Giá trị r khi dự đoán với tất cả các biến**
#
# Mô hình SVR

# %%
ALL_2016_1_svr = pd.DataFrame(np.array(y_svr_ALL_2016_pred),columns=['y_pred'])
ALL_2016_2_svr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
ALL_2016_svr = pd.concat([ALL_2016_1_svr, ALL_2016_2_svr], axis=1, join='inner')

ALL_2017_1_svr = pd.DataFrame(np.array(y_svr_ALL_2017_pred),columns=['y_pred'])
ALL_2017_2_svr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
ALL_2017_svr = pd.concat([ALL_2017_1_svr, ALL_2017_2_svr], axis=1, join='inner')

ALL_2018_1_svr = pd.DataFrame(np.array(y_svr_ALL_2018_pred),columns=['y_pred'])
ALL_2018_2_svr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
ALL_2018_svr = pd.concat([ALL_2018_1_svr, ALL_2018_2_svr], axis=1, join='inner')

ALL_2019_1_svr = pd.DataFrame(np.array(y_svr_ALL_2019_pred),columns=['y_pred'])
ALL_2019_2_svr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
ALL_2019_svr = pd.concat([ALL_2019_1_svr, ALL_2019_2_svr], axis=1, join='inner')

ALL_2020_1_svr = pd.DataFrame(np.array(y_svr_ALL_2020_pred),columns=['y_pred'])
ALL_2020_2_svr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
ALL_2020_svr = pd.concat([ALL_2020_1_svr, ALL_2020_2_svr], axis=1, join='inner')

print(ALL_2016_svr.corr())
print(ALL_2017_svr.corr())
print(ALL_2018_svr.corr())
print(ALL_2019_svr.corr())
print(ALL_2020_svr.corr())
# Out:
#         y_pred  y_test
# y_pred  1.0000  0.6792
# y_test  0.6792  1.0000
#           y_pred    y_test
# y_pred  1.000000  0.706028
# y_test  0.706028  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.780782
# y_test  0.780782  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.696823
# y_test  0.696823  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.757648
# y_test  0.757648  1.000000

# %% [markdown]
# Mô hình RFR

# %%
ALL_2016_1_rfr = pd.DataFrame(np.array(y_rfr_ALL_2016_pred),columns=['y_pred'])
ALL_2016_2_rfr = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
ALL_2016_rfr = pd.concat([ALL_2016_1_rfr, ALL_2016_2_rfr], axis=1, join='inner')

ALL_2017_1_rfr = pd.DataFrame(np.array(y_rfr_ALL_2017_pred),columns=['y_pred'])
ALL_2017_2_rfr = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
ALL_2017_rfr = pd.concat([ALL_2017_1_rfr, ALL_2017_2_rfr], axis=1, join='inner')

ALL_2018_1_rfr = pd.DataFrame(np.array(y_rfr_ALL_2018_pred),columns=['y_pred'])
ALL_2018_2_rfr = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
ALL_2018_rfr = pd.concat([ALL_2018_1_rfr, ALL_2018_2_rfr], axis=1, join='inner')

ALL_2019_1_rfr = pd.DataFrame(np.array(y_rfr_ALL_2019_pred),columns=['y_pred'])
ALL_2019_2_rfr = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
ALL_2019_rfr = pd.concat([ALL_2019_1_rfr, ALL_2019_2_rfr], axis=1, join='inner')

ALL_2020_1_rfr = pd.DataFrame(np.array(y_rfr_ALL_2020_pred),columns=['y_pred'])
ALL_2020_2_rfr = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
ALL_2020_rfr = pd.concat([ALL_2020_1_rfr, ALL_2020_2_rfr], axis=1, join='inner')

print(ALL_2016_rfr.corr())
print(ALL_2017_rfr.corr())
print(ALL_2018_rfr.corr())
print(ALL_2019_rfr.corr())
print(ALL_2020_rfr.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.704671
# y_test  0.704671  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.701198
# y_test  0.701198  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.788908
# y_test  0.788908  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.720664
# y_test  0.720664  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.781724
# y_test  0.781724  1.000000

# %% [markdown]
# Mô hình Ridge

# %%
ALL_2016_1_ridge = pd.DataFrame(np.array(y_ridge_ALL_2016_pred),columns=['y_pred'])
ALL_2016_2_ridge = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
ALL_2016_ridge = pd.concat([ALL_2016_1_ridge, ALL_2016_2_ridge], axis=1, join='inner')

ALL_2017_1_ridge = pd.DataFrame(np.array(y_ridge_ALL_2017_pred),columns=['y_pred'])
ALL_2017_2_ridge = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
ALL_2017_ridge = pd.concat([ALL_2017_1_ridge, ALL_2017_2_ridge], axis=1, join='inner')

ALL_2018_1_ridge = pd.DataFrame(np.array(y_ridge_ALL_2018_pred),columns=['y_pred'])
ALL_2018_2_ridge = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
ALL_2018_ridge = pd.concat([ALL_2018_1_ridge, ALL_2018_2_ridge], axis=1, join='inner')

ALL_2019_1_ridge = pd.DataFrame(np.array(y_ridge_ALL_2019_pred),columns=['y_pred'])
ALL_2019_2_ridge = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
ALL_2019_ridge = pd.concat([ALL_2019_1_ridge, ALL_2019_2_ridge], axis=1, join='inner')

ALL_2020_1_ridge = pd.DataFrame(np.array(y_ridge_ALL_2020_pred),columns=['y_pred'])
ALL_2020_2_ridge = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
ALL_2020_ridge = pd.concat([ALL_2020_1_ridge, ALL_2020_2_ridge], axis=1, join='inner')

print(ALL_2016_ridge.corr())
print(ALL_2017_ridge.corr())
print(ALL_2018_ridge.corr())
print(ALL_2019_ridge.corr())
print(ALL_2020_ridge.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.703553
# y_test  0.703553  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.711317
# y_test  0.711317  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.797028
# y_test  0.797028  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.729344
# y_test  0.729344  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.798568
# y_test  0.798568  1.000000

# %% [markdown]
# Mô hình Lasso

# %%
ALL_2016_1_lasso = pd.DataFrame(np.array(y_lasso_ALL_2016_pred),columns=['y_pred'])
ALL_2016_2_lasso = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
ALL_2016_lasso = pd.concat([ALL_2016_1_lasso, ALL_2016_2_lasso], axis=1, join='inner')

ALL_2017_1_lasso = pd.DataFrame(np.array(y_lasso_ALL_2017_pred),columns=['y_pred'])
ALL_2017_2_lasso = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
ALL_2017_lasso = pd.concat([ALL_2017_1_lasso, ALL_2017_2_lasso], axis=1, join='inner')

ALL_2018_1_lasso = pd.DataFrame(np.array(y_lasso_ALL_2018_pred),columns=['y_pred'])
ALL_2018_2_lasso = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
ALL_2018_lasso = pd.concat([ALL_2018_1_lasso, ALL_2018_2_lasso], axis=1, join='inner')

ALL_2019_1_lasso = pd.DataFrame(np.array(y_lasso_ALL_2019_pred),columns=['y_pred'])
ALL_2019_2_lasso = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
ALL_2019_lasso = pd.concat([ALL_2019_1_lasso, ALL_2019_2_lasso], axis=1, join='inner')

ALL_2020_1_lasso = pd.DataFrame(np.array(y_lasso_ALL_2020_pred),columns=['y_pred'])
ALL_2020_2_lasso = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
ALL_2020_lasso = pd.concat([ALL_2020_1_lasso, ALL_2020_2_lasso], axis=1, join='inner')

print(ALL_2016_lasso.corr())
print(ALL_2017_lasso.corr())
print(ALL_2018_lasso.corr())
print(ALL_2019_lasso.corr())
print(ALL_2020_lasso.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.710443
# y_test  0.710443  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.709987
# y_test  0.709987  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.793005
# y_test  0.793005  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.731688
# y_test  0.731688  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.794225
# y_test  0.794225  1.000000

# %% [markdown]
# Mô hình Decision Tree

# %%
ALL_2016_1_dtree = pd.DataFrame(np.array(y_dtree_ALL_2016_pred),columns=['y_pred'])
ALL_2016_2_dtree = pd.DataFrame(np.array(y_2016_test),columns=['y_test'])
ALL_2016_dtree = pd.concat([ALL_2016_1_dtree, ALL_2016_2_dtree], axis=1, join='inner')

ALL_2017_1_dtree = pd.DataFrame(np.array(y_dtree_ALL_2017_pred),columns=['y_pred'])
ALL_2017_2_dtree = pd.DataFrame(np.array(y_2017_test),columns=['y_test'])
ALL_2017_dtree = pd.concat([ALL_2017_1_dtree, ALL_2017_2_dtree], axis=1, join='inner')

ALL_2018_1_dtree = pd.DataFrame(np.array(y_dtree_ALL_2018_pred),columns=['y_pred'])
ALL_2018_2_dtree = pd.DataFrame(np.array(y_2018_test),columns=['y_test'])
ALL_2018_dtree = pd.concat([ALL_2018_1_dtree, ALL_2018_2_dtree], axis=1, join='inner')

ALL_2019_1_dtree = pd.DataFrame(np.array(y_dtree_ALL_2019_pred),columns=['y_pred'])
ALL_2019_2_dtree = pd.DataFrame(np.array(y_2019_test),columns=['y_test'])
ALL_2019_dtree = pd.concat([ALL_2019_1_dtree, ALL_2019_2_dtree], axis=1, join='inner')

ALL_2020_1_dtree = pd.DataFrame(np.array(y_dtree_ALL_2020_pred),columns=['y_pred'])
ALL_2020_2_dtree = pd.DataFrame(np.array(y_2020_test),columns=['y_test'])
ALL_2020_dtree = pd.concat([ALL_2020_1_dtree, ALL_2020_2_dtree], axis=1, join='inner')

print(ALL_2016_dtree.corr())
print(ALL_2017_dtree.corr())
print(ALL_2018_dtree.corr())
print(ALL_2019_dtree.corr())
print(ALL_2020_dtree.corr())
# Out:
#           y_pred    y_test
# y_pred  1.000000  0.406899
# y_test  0.406899  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.463559
# y_test  0.463559  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.580065
# y_test  0.580065  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.565941
# y_test  0.565941  1.000000
#           y_pred    y_test
# y_pred  1.000000  0.529006
# y_test  0.529006  1.000000

# %% [markdown]
# # ONE-WAY ANOVA

# %%
from scipy.stats import f_oneway

# %% [markdown]
# Khi dự đoán với biến CT

# %%
f_oneway(y_svr_CT_2016_pred,y_rfr_CT_2016_pred,y_ridge_CT_2016_pred,y_lasso_CT_2016_pred,y_2016_test)
# Out:
# F_onewayResult(statistic=0.16438367364206566, pvalue=0.9564257277868318)

# %%
f_oneway(y_svr_CT_2017_pred,y_rfr_CT_2017_pred,y_ridge_CT_2017_pred,y_lasso_CT_2017_pred,y_2017_test)
# Out:
# F_onewayResult(statistic=0.8733001648664257, pvalue=0.47915411110081796)

# %%
f_oneway(y_svr_CT_2018_pred,y_rfr_CT_2018_pred,y_ridge_CT_2018_pred,y_lasso_CT_2018_pred,y_2018_test)
# Out:
# F_onewayResult(statistic=0.24668458289609074, pvalue=0.9117544457919095)

# %%
f_oneway(y_svr_CT_2019_pred,y_rfr_CT_2019_pred,y_ridge_CT_2019_pred,y_lasso_CT_2019_pred,y_2019_test)
# Out:
# F_onewayResult(statistic=0.6086735949885683, pvalue=0.6564304553296625)

# %%
f_oneway(y_svr_CT_2020_pred,y_rfr_CT_2020_pred,y_ridge_CT_2020_pred,y_lasso_CT_2020_pred,y_2020_test)
# Out:
# F_onewayResult(statistic=0.021459083075834263, pvalue=0.9991039209338567)

# %% [markdown]
# Khi dự đoán với biến NDVI

# %%
f_oneway(y_svr_NDVI_2016_pred,y_rfr_NDVI_2016_pred,y_ridge_NDVI_2016_pred,y_lasso_NDVI_2016_pred,y_2016_test)
# Out:
# F_onewayResult(statistic=0.35522543344929014, pvalue=0.8405062114799124)

# %%
f_oneway(y_svr_NDVI_2017_pred,y_rfr_NDVI_2017_pred,y_ridge_NDVI_2017_pred,y_lasso_NDVI_2017_pred,y_2017_test)
# Out:
# F_onewayResult(statistic=1.0327789603407176, pvalue=0.3889018279365522)

# %%
f_oneway(y_svr_NDVI_2018_pred,y_rfr_NDVI_2018_pred,y_ridge_NDVI_2018_pred,y_lasso_NDVI_2018_pred,y_2018_test)
# Out:
# F_onewayResult(statistic=0.015212077575075244, pvalue=0.999545937120349)

# %%
f_oneway(y_svr_NDVI_2019_pred,y_rfr_NDVI_2019_pred,y_ridge_NDVI_2019_pred,y_lasso_NDVI_2019_pred,y_2019_test)
# Out:
# F_onewayResult(statistic=0.012746212284134993, pvalue=0.9996801249829782)

# %%
f_oneway(y_svr_NDVI_2020_pred,y_rfr_NDVI_2020_pred,y_ridge_NDVI_2020_pred,y_lasso_NDVI_2020_pred,y_2020_test)
# Out:
# F_onewayResult(statistic=0.11438523501381789, pvalue=0.9774810437783449)

# %% [markdown]
# Khi dự đoán với các biến NDVI và CT

# %%
f_oneway(y_svr_NDVI_CT_2016_pred,y_rfr_NDVI_CT_2016_pred,y_ridge_NDVI_CT_2016_pred,y_lasso_NDVI_CT_2016_pred,y_2016_test)
# Out:
# F_onewayResult(statistic=0.17610610799732124, pvalue=0.9507444081910622)

# %%
f_oneway(y_svr_NDVI_CT_2017_pred,y_rfr_NDVI_CT_2017_pred,y_ridge_NDVI_CT_2017_pred,y_lasso_NDVI_CT_2017_pred,y_2017_test)
# Out:
# F_onewayResult(statistic=0.7548940964535994, pvalue=0.5547106540333)

# %%
f_oneway(y_svr_NDVI_CT_2018_pred,y_rfr_NDVI_CT_2018_pred,y_ridge_NDVI_CT_2018_pred,y_lasso_NDVI_CT_2018_pred,y_2018_test)
# Out:
# F_onewayResult(statistic=0.06601597630220196, pvalue=0.9920062512010184)

# %%
f_oneway(y_svr_NDVI_CT_2019_pred,y_rfr_NDVI_CT_2019_pred,y_ridge_NDVI_CT_2019_pred,y_lasso_NDVI_CT_2019_pred,y_2019_test)
# Out:
# F_onewayResult(statistic=0.1925937393887406, pvalue=0.9423335272047766)

# %%
f_oneway(y_svr_NDVI_CT_2020_pred,y_rfr_NDVI_CT_2020_pred,y_ridge_NDVI_CT_2020_pred,y_lasso_NDVI_CT_2020_pred,y_2020_test)
# Out:
# F_onewayResult(statistic=0.04106067863062829, pvalue=0.9968036193874527)

# %% [markdown]
# Khi dự đoán với các biến nhóm đặc điểm nông học

# %%
f_oneway(y_svr_AGR_2016_pred,y_rfr_AGR_2016_pred,y_ridge_AGR_2016_pred,y_lasso_AGR_2016_pred,y_2016_test)
# Out:
# F_onewayResult(statistic=0.03624680544064394, pvalue=0.9974929120471558)

# %%
f_oneway(y_svr_AGR_2017_pred,y_rfr_AGR_2017_pred,y_ridge_AGR_2017_pred,y_lasso_AGR_2017_pred,y_2017_test)
# Out:
# F_onewayResult(statistic=0.92989536435803, pvalue=0.4455654846509287)

# %%
f_oneway(y_svr_AGR_2018_pred,y_rfr_AGR_2018_pred,y_ridge_AGR_2018_pred,y_lasso_AGR_2018_pred,y_2018_test)
# Out:
# F_onewayResult(statistic=0.34554770283743796, pvalue=0.8472394791113871)

# %%
f_oneway(y_svr_AGR_2019_pred,y_rfr_AGR_2019_pred,y_ridge_AGR_2019_pred,y_lasso_AGR_2019_pred,y_2019_test)
# Out:
# F_onewayResult(statistic=1.5360747682529277, pvalue=0.18923315833700016)

# %%
f_oneway(y_svr_AGR_2020_pred,y_rfr_AGR_2020_pred,y_ridge_AGR_2020_pred,y_lasso_AGR_2020_pred,y_2020_test)
# Out:
# F_onewayResult(statistic=0.47397754714445534, pvalue=0.7548852957849849)

# %% [markdown]
# Khi dự đoán với tất cả các biến

# %%
f_oneway(y_svr_ALL_2016_pred,y_rfr_ALL_2016_pred,y_ridge_ALL_2016_pred,y_lasso_ALL_2016_pred,y_2016_test)
# Out:
# F_onewayResult(statistic=0.13500897629056746, pvalue=0.9694610942794066)

# %%
f_oneway(y_svr_ALL_2017_pred,y_rfr_ALL_2017_pred,y_ridge_ALL_2017_pred,y_lasso_ALL_2017_pred,y_2017_test)
# Out:
# F_onewayResult(statistic=0.9079423196376734, pvalue=0.45839308905439147)

# %%
f_oneway(y_svr_ALL_2018_pred,y_rfr_ALL_2018_pred,y_ridge_ALL_2018_pred,y_lasso_ALL_2018_pred,y_2018_test)
# Out:
# F_onewayResult(statistic=0.15570034674237143, pvalue=0.9604668277272819)

# %%
f_oneway(y_svr_ALL_2019_pred,y_rfr_ALL_2019_pred,y_ridge_ALL_2019_pred,y_lasso_ALL_2019_pred,y_2019_test)
# Out:
# F_onewayResult(statistic=1.0137382792218312, pvalue=0.398991317008574)

# %%
f_oneway(y_svr_ALL_2020_pred,y_rfr_ALL_2020_pred,y_ridge_ALL_2020_pred,y_lasso_ALL_2020_pred,y_2020_test)
# Out:
# F_onewayResult(statistic=0.14810170424909425, pvalue=0.9638758126220835)
